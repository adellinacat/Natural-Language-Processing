# %% [markdown]
# ### 11. Модель Transformer-1
#
# **Задание**
#
# Разобраться с моделью перевода (без механизма внимания) как она устроена, запустить для перевода с русского на английский (при желании можно взять другие пары языков)

# %% [markdown]
# Подготовим окружение

# %%
# !pip install tensorflow_datasets
# Out:
# Requirement already satisfied: tensorflow_datasets in /usr/local/lib/python3.10/dist-packages (4.9.3)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from tensorflow_datasets) (1.4.0)
# Requirement already satisfied: array-record in /usr/local/lib/python3.10/dist-packages (from tensorflow_datasets) (0.5.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow_datasets) (8.1.7)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from tensorflow_datasets) (0.1.8)
# Requirement already satisfied: etils[enp,epath,etree]>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_datasets) (1.5.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tensorflow_datasets) (1.23.5)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow_datasets) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow_datasets) (3.20.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from tensorflow_datasets) (5.9.5)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_datasets) (2.31.0)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow_datasets) (1.14.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from tensorflow_datasets) (2.3.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow_datasets) (0.10.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from tensorflow_datasets) (4.66.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from tensorflow_datasets) (1.14.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow_datasets) (2023.6.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow_datasets) (6.1.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow_datasets) (4.5.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow_datasets) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->tensorflow_datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->tensorflow_datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->tensorflow_datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->tensorflow_datasets) (2023.7.22)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from promise->tensorflow_datasets) (1.16.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata->tensorflow_datasets) (1.61.0)

# %%
# !pip install resource
# Out:
# Collecting resource
#   Downloading Resource-0.2.1-py2.py3-none-any.whl (25 kB)
# Collecting JsonForm>=0.0.2 (from resource)
#   Downloading JsonForm-0.0.2.tar.gz (2.4 kB)
#   Preparing metadata (setup.py) ... done
# Collecting JsonSir>=0.0.2 (from resource)
#   Downloading JsonSir-0.0.2.tar.gz (2.2 kB)
#   Preparing metadata (setup.py) ... done
# Collecting python-easyconfig>=0.1.0 (from resource)
#   Downloading Python_EasyConfig-0.1.7-py2.py3-none-any.whl (5.4 kB)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from JsonForm>=0.0.2->resource) (4.19.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from python-easyconfig>=0.1.0->resource) (6.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from python-easyconfig>=0.1.0->resource) (1.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->JsonForm>=0.0.2->resource) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->JsonForm>=0.0.2->resource) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->JsonForm>=0.0.2->resource) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->JsonForm>=0.0.2->resource) (0.11.0)
# Building wheels for collected packages: JsonForm, JsonSir
#   Building wheel for JsonForm (setup.py) ... done
#   Created wheel for JsonForm: filename=JsonForm-0.0.2-py3-none-any.whl size=3313 sha256=6e78919fa08f94ec4e7f4aaae1ed99fc8bca0434edbcacaa6ac4e819f869c8c1
#   Stored in directory: /root/.cache/pip/wheels/b6/e5/87/11026246d3bd4ad67c0615682d2d6748bbd9a40ac0490882bd
#   Building wheel for JsonSir (setup.py) ... done
#   Created wheel for JsonSir: filename=JsonSir-0.0.2-py3-none-any.whl size=4753 sha256=ea19572be0511ac640f3e70ff2a87e9078c8de42c34b7cfbdc02bb89906b6a04
#   Stored in directory: /root/.cache/pip/wheels/1d/4c/d3/4d9757425983b43eb709be1043d82cd03fb863ce5f56f117e6
# Successfully built JsonForm JsonSir
# Installing collected packages: JsonSir, python-easyconfig, JsonForm, resource
# Successfully installed JsonForm-0.0.2 JsonSir-0.0.2 python-easyconfig-0.1.7 resource-0.2.1

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.35.0-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 43.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.19.0-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 34.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 78.7 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 62.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 36.6 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.35.0

# %%
import transformers
import tensorflow_datasets as tfds
import tensorflow as tf

import time
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# %matplotlib inline
from sklearn.model_selection import train_test_split

# %% [markdown]
# Посмотрим на данные

# %%
examples, metadata = tfds.load('ted_hrlr_translate/ru_to_en', with_info=True,
                               as_supervised=True)
train_examples, val_examples = examples['train'], examples['validation']
# Out:
# Downloading and preparing dataset 124.94 MiB (download: 124.94 MiB, generated: Unknown size, total: 124.94 MiB) to /root/tensorflow_datasets/ted_hrlr_translate/ru_to_en/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/208106 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/ted_hrlr_translate/ru_to_en/1.0.0.incompleteLIY1BF/ted_hrlr_translate-trai…
# Generating validation examples...:   0%|          | 0/4805 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/ted_hrlr_translate/ru_to_en/1.0.0.incompleteLIY1BF/ted_hrlr_translate-vali…
# Generating test examples...:   0%|          | 0/5476 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/ted_hrlr_translate/ru_to_en/1.0.0.incompleteLIY1BF/ted_hrlr_translate-test…
# Dataset ted_hrlr_translate downloaded and prepared to /root/tensorflow_datasets/ted_hrlr_translate/ru_to_en/1.0.0. Subsequent calls will reuse this data.

# %% [markdown]
# Создание токенизатора

# %%
tokenizer_en = tfds.deprecated.text.SubwordTextEncoder.build_from_corpus(
    (en.numpy() for pt, en in train_examples), target_vocab_size=2**13)

tokenizer_pt = tfds.deprecated.text.SubwordTextEncoder.build_from_corpus(
    (pt.numpy() for pt, en in train_examples), target_vocab_size=2**13)

# %%
BUFFER_SIZE = 20000
BATCH_SIZE = 64
MAX_LENGTH = 40

# %%
# добавим начальный и конечный токен

def encode(lang1, lang2):
  lang1 = [tokenizer_pt.vocab_size] + tokenizer_pt.encode(
      lang1.numpy()) + [tokenizer_pt.vocab_size+1]

  lang2 = [tokenizer_en.vocab_size] + tokenizer_en.encode(
      lang2.numpy()) + [tokenizer_en.vocab_size+1]

  return lang1, lang2

# %%
# энкодер
def tf_encode(pt, en):
  result_pt, result_en = tf.py_function(encode, [pt, en], [tf.int64, tf.int64])
  result_pt.set_shape([None])
  result_en.set_shape([None])

  return result_pt, result_en

# %%
def filter_max_length(x, y, max_length=MAX_LENGTH):
  return tf.logical_and(tf.size(x) <= max_length,
                        tf.size(y) <= max_length)

# %%
# кэшируем набор данных в памяти, чтобы ускорить чтение из него

train_dataset = train_examples.map(tf_encode)
train_dataset = train_dataset.filter(filter_max_length)

train_dataset = train_dataset.cache()
train_dataset = train_dataset.shuffle(BUFFER_SIZE).padded_batch(BATCH_SIZE)
train_dataset = train_dataset.prefetch(tf.data.experimental.AUTOTUNE)


val_dataset = val_examples.map(tf_encode)
val_dataset = val_dataset.filter(filter_max_length).padded_batch(BATCH_SIZE)

# %%
pt_batch, en_batch = next(iter(val_dataset))
pt_batch, en_batch
# Out:
# (<tf.Tensor: shape=(64, 38), dtype=int64, numpy=
#  array([[8179,   57,   86, ...,    0,    0,    0],
#         [8179,    3,   38, ...,    0,    0,    0],
#         [8179,   57,  135, ...,    0,    0,    0],
#         ...,
#         [8179,    3,    7, ...,    0,    0,    0],
#         [8179,  138,  250, ...,    0,    0,    0],
#         [8179,   19,    7, ...,    0,    0,    0]])>,
#  <tf.Tensor: shape=(64, 40), dtype=int64, numpy=
#  array([[8245,   90,  101, ...,    0,    0,    0],
#         [8245,   70,   25, ...,    0,    0,    0],
#         [8245,   90,  153, ...,    0,    0,    0],
#         ...,
#         [8245,    4,   18, ...,    0,    0,    0],
#         [8245,   19,   59, ...,    0,    0,    0],
#         [8245,   24,   18, ...,    0,    0,    0]])>)

# %% [markdown]
# Позиционное кодирование

# %%
def get_angles(pos, i, d_model):
  angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
  return pos * angle_rates

# %%
def positional_encoding(position, d_model):
  angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)

 # применим sin к четным индексам в массиве
  angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])

  #применим cos к нечетным индексам в массиве
  angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

  pos_encoding = angle_rads[np.newaxis, ...]

  return tf.cast(pos_encoding, dtype=tf.float32)

# %%
#Функция masking

def create_padding_mask(seq):
  seq = tf.cast(tf.math.equal(seq, 0), tf.float32)

  return seq[:, tf.newaxis, tf.newaxis, :]

# %%
def create_look_ahead_mask(size):
  mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
  return mask

# %% [markdown]
# Attention

# %%
def scaled_dot_product_attention(q, k, v, mask):
  """Calculate the attention weights.
  q, k, v must have matching leading dimensions.
  k, v must have matching penultimate dimension, i.e.: seq_len_k = seq_len_v.
  The mask has different shapes depending on its type(padding or look ahead)
  but it must be broadcastable for addition.

  Args:
    q: query shape == (..., seq_len_q, depth)
    k: key shape == (..., seq_len_k, depth)
    v: value shape == (..., seq_len_v, depth_v)
    mask: Float tensor with shape broadcastable
          to (..., seq_len_q, seq_len_k). Defaults to None.

  Returns:
    output, attention_weights
  """

  matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)

  # scale matmul_qk
  dk = tf.cast(tf.shape(k)[-1], tf.float32)
  scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

  # add the mask to the scaled tensor.
  if mask is not None:
    scaled_attention_logits += (mask * -1e9)

  # softmax is normalized on the last axis (seq_len_k) so that the scores
  # add up to 1.
  attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)

  output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)

  return output, attention_weights

# %%
#функция вывода
def print_out(q, k, v):
  temp_out, temp_attn = scaled_dot_product_attention(
      q, k, v, None)
  print ('Attention weights are:')
  print (temp_attn)
  print ('Output is:')
  print (temp_out)

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads):
    super(MultiHeadAttention, self).__init__()
    self.num_heads = num_heads
    self.d_model = d_model

    assert d_model % self.num_heads == 0

    self.depth = d_model // self.num_heads

    self.wq = tf.keras.layers.Dense(d_model)
    self.wk = tf.keras.layers.Dense(d_model)
    self.wv = tf.keras.layers.Dense(d_model)

    self.dense = tf.keras.layers.Dense(d_model)

  def split_heads(self, x, batch_size):
    """Split the last dimension into (num_heads, depth).
    Transpose the result such that the shape is (batch_size, num_heads, seq_len, depth)
    """
    x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
    return tf.transpose(x, perm=[0, 2, 1, 3])

  def call(self, v, k, q, mask):
    batch_size = tf.shape(q)[0]

    q = self.wq(q)
    k = self.wk(k)
    v = self.wv(v)

    q = self.split_heads(q, batch_size)
    k = self.split_heads(k, batch_size)
    v = self.split_heads(v, batch_size)

    # scaled_attention.shape == (batch_size, num_heads, seq_len_q, depth)
    # attention_weights.shape == (batch_size, num_heads, seq_len_q, seq_len_k)
    scaled_attention, attention_weights = scaled_dot_product_attention(
        q, k, v, mask)

    scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])

    concat_attention = tf.reshape(scaled_attention,
                                  (batch_size, -1, self.d_model))

    output = self.dense(concat_attention)

    return output, attention_weights

# %%
def point_wise_feed_forward_network(d_model, dff):
  return tf.keras.Sequential([
      tf.keras.layers.Dense(dff, activation='relu'),  # (batch_size, seq_len, dff)
      tf.keras.layers.Dense(d_model)  # (batch_size, seq_len, d_model)
  ])

# %% [markdown]
# Слой Encoder

# %%
class EncoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate=0.1):
    super(EncoderLayer, self).__init__()

    self.mha = MultiHeadAttention(d_model, num_heads)
    self.ffn = point_wise_feed_forward_network(d_model, dff)

    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)

  def call(self, x, training, mask):

    attn_output, _ = self.mha(x, x, x, mask)
    attn_output = self.dropout1(attn_output, training=training)
    out1 = self.layernorm1(x + attn_output)

    ffn_output = self.ffn(out1)
    ffn_output = self.dropout2(ffn_output, training=training)
    out2 = self.layernorm2(out1 + ffn_output)

    return out2

# %% [markdown]
# Слой Decoder

# %%
class DecoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate=0.1):
    super(DecoderLayer, self).__init__()

    self.mha1 = MultiHeadAttention(d_model, num_heads)
    self.mha2 = MultiHeadAttention(d_model, num_heads)

    self.ffn = point_wise_feed_forward_network(d_model, dff)

    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)
    self.dropout3 = tf.keras.layers.Dropout(rate)


  def call(self, x, enc_output, training,
           look_ahead_mask, padding_mask):


    attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)
    attn1 = self.dropout1(attn1, training=training)
    out1 = self.layernorm1(attn1 + x)

    attn2, attn_weights_block2 = self.mha2(
        enc_output, enc_output, out1, padding_mask)
    attn2 = self.dropout2(attn2, training=training)
    out2 = self.layernorm2(attn2 + out1)

    ffn_output = self.ffn(out2)
    ffn_output = self.dropout3(ffn_output, training=training)
    out3 = self.layernorm3(ffn_output + out2)

    return out3, attn_weights_block1, attn_weights_block2

# %% [markdown]
# Энкодер состоит из:
#
# 1. Встраивание входных данных
# 2. Позиционное кодирование
# 3. N слоев кодировщика

# %%
class Encoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size,
               maximum_position_encoding, rate=0.1):
    super(Encoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers

    self.embedding = tf.keras.layers.Embedding(input_vocab_size, d_model)
    self.pos_encoding = positional_encoding(maximum_position_encoding,
                                            self.d_model)


    self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate)
                       for _ in range(num_layers)]

    self.dropout = tf.keras.layers.Dropout(rate)

  def call(self, x, training, mask):

    seq_len = tf.shape(x)[1]

    # добавление эмбеддинга и кодировка позиции
    x = self.embedding(x)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]

    x = self.dropout(x, training=training)

    for i in range(self.num_layers):
      x = self.enc_layers[i](x, training, mask)

    return x

# %% [markdown]
# Декодер состоит из:
#
# 1. Выходное внедрение
# 2. Позиционное кодирование
# 3. N слоев декодера

# %%
class Decoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff, target_vocab_size,
               maximum_position_encoding, rate=0.1):
    super(Decoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers

    self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
    self.pos_encoding = positional_encoding(maximum_position_encoding, d_model)

    self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate)
                       for _ in range(num_layers)]
    self.dropout = tf.keras.layers.Dropout(rate)

  def call(self, x, enc_output, training,
           look_ahead_mask, padding_mask):

    seq_len = tf.shape(x)[1]
    attention_weights = {}

    x = self.embedding(x)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]

    x = self.dropout(x, training=training)

    for i in range(self.num_layers):
      x, block1, block2 = self.dec_layers[i](x, enc_output, training,
                                             look_ahead_mask, padding_mask)

      attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
      attention_weights['decoder_layer{}_block2'.format(i+1)] = block2

    return x, attention_weights

# %% [markdown]
# Создание трансформера
#
# Трансформатор состоит из encoder, decoder и конечного линейного слоя. Выходные данные декодера являются входными данными для линейного слоя, и его выходные данные возвращаются.

# %%
class Transformer(tf.keras.Model):
  def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size,
               target_vocab_size, pe_input, pe_target, rate=0.1):
    super(Transformer, self).__init__()

    self.encoder = Encoder(num_layers, d_model, num_heads, dff,
                           input_vocab_size, pe_input, rate)

    self.decoder = Decoder(num_layers, d_model, num_heads, dff,
                           target_vocab_size, pe_target, rate)

    self.final_layer = tf.keras.layers.Dense(target_vocab_size)

  def call(self, inp, tar, training, enc_padding_mask,
           look_ahead_mask, dec_padding_mask):

    enc_output = self.encoder(inp, training, enc_padding_mask)

    dec_output, attention_weights = self.decoder(
        tar, enc_output, training, look_ahead_mask, dec_padding_mask)

    final_output = self.final_layer(dec_output)

    return final_output, attention_weights

# %%
num_layers = 4
d_model = 128
dff = 512
num_heads = 8

input_vocab_size = tokenizer_pt.vocab_size + 2
target_vocab_size = tokenizer_en.vocab_size + 2
dropout_rate = 0.1
optimizer = tf.keras.optimizers.Adam()

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

# %%
# добавим функцию потерь
def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_sum(loss_)/tf.reduce_sum(mask)

#добавим функцию точности
def accuracy_function(real, pred):
  accuracies = tf.equal(real, tf.argmax(pred, axis=2))

  mask = tf.math.logical_not(tf.math.equal(real, 0))
  accuracies = tf.math.logical_and(mask, accuracies)

  accuracies = tf.cast(accuracies, dtype=tf.float32)
  mask = tf.cast(mask, dtype=tf.float32)
  return tf.reduce_sum(accuracies)/tf.reduce_sum(mask)

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

# %%
transformer = Transformer(num_layers, d_model, num_heads, dff,
                          input_vocab_size, target_vocab_size,
                          pe_input=input_vocab_size,
                          pe_target=target_vocab_size,
                          rate=dropout_rate)

# %%
# функция задания масок
def create_masks(inp, tar):
  enc_padding_mask = create_padding_mask(inp)
  dec_padding_mask = create_padding_mask(inp)

  look_ahead_mask = create_look_ahead_mask(tf.shape(tar)[1])
  dec_target_padding_mask = create_padding_mask(tar)
  combined_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)

  return enc_padding_mask, combined_mask, dec_padding_mask

# %%
checkpoint_path = "./checkpoints/train"

ckpt = tf.train.Checkpoint(transformer=transformer,
                           optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# если контрольная точка существует, восстановить последнюю контрольную точку.
if ckpt_manager.latest_checkpoint:
  ckpt.restore(ckpt_manager.latest_checkpoint)
  print ('Latest checkpoint restored!!')

# %% [markdown]
# Обучим модель

# %%
EPOCHS = 25

# %%
train_step_signature = [
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
]

@tf.function(input_signature=train_step_signature)
def train_step(inp, tar):
  tar_inp = tar[:, :-1]
  tar_real = tar[:, 1:]

  enc_padding_mask, combined_mask, dec_padding_mask = create_masks(inp, tar_inp)

  with tf.GradientTape() as tape:
    predictions, _ = transformer(inp, tar_inp,
                                 True,
                                 enc_padding_mask,
                                 combined_mask,
                                 dec_padding_mask)
    loss = loss_function(tar_real, predictions)

  gradients = tape.gradient(loss, transformer.trainable_variables)
  optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))

  train_loss(loss)
  train_accuracy(accuracy_function(tar_real, predictions))

# %%
for epoch in range(EPOCHS):
  start = time.time()

  train_loss.reset_states()
  train_accuracy.reset_states()

  # inp -> portuguese, tar -> english
  for (batch, (inp, tar)) in enumerate(train_dataset):
    train_step(inp, tar)

    if batch % 50 == 0:
      print ('Epoch {} Batch {} Loss {:.4f} Accuracy {:.4f}'.format(
          epoch + 1, batch, train_loss.result(), train_accuracy.result()))

  if (epoch + 1) % 5 == 0:
    ckpt_save_path = ckpt_manager.save()
    print ('Saving checkpoint for epoch {} at {}'.format(epoch+1,
                                                         ckpt_save_path))

  print ('Epoch {} Loss {:.4f} Accuracy {:.4f}'.format(epoch + 1,
                                                train_loss.result(),
                                                train_accuracy.result()))

  print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 9.0284 Accuracy 0.0000
# Epoch 1 Batch 50 Loss 7.1591 Accuracy 0.0523
# Epoch 1 Batch 100 Loss 6.8350 Accuracy 0.0533
# Epoch 1 Batch 150 Loss 6.7167 Accuracy 0.0543
# Epoch 1 Batch 200 Loss 6.6295 Accuracy 0.0638
# Epoch 1 Batch 250 Loss 6.5607 Accuracy 0.0704
# Epoch 1 Batch 300 Loss 6.5102 Accuracy 0.0751
# Epoch 1 Batch 350 Loss 6.4747 Accuracy 0.0785
# Epoch 1 Batch 400 Loss 6.4432 Accuracy 0.0810
# Epoch 1 Batch 450 Loss 6.4199 Accuracy 0.0832
# Epoch 1 Batch 500 Loss 6.3980 Accuracy 0.0847
# Epoch 1 Batch 550 Loss 6.3806 Accuracy 0.0868
# Epoch 1 Batch 600 Loss 6.3615 Accuracy 0.0887
# Epoch 1 Batch 650 Loss 6.3457 Accuracy 0.0906
# Epoch 1 Batch 700 Loss 6.3289 Accuracy 0.0924
# Epoch 1 Batch 750 Loss 6.3139 Accuracy 0.0942
# Epoch 1 Batch 800 Loss 6.3006 Accuracy 0.0958
# Epoch 1 Batch 850 Loss 6.2876 Accuracy 0.0975
# Epoch 1 Batch 900 Loss 6.2758 Accuracy 0.0990
# Epoch 1 Batch 950 Loss 6.2658 Accuracy 0.1004
# Epoch 1 Batch 1000 Loss 6.2550 Accuracy 0.1018
# Epoch 1 Batch 1050 Loss 6.2453 Accuracy 0.1031
# Epoch 1 Batch 1100 Loss 6.2364 Accuracy 0.1042
# Epoch 1 Batch 1150 Loss 6.2275 Accuracy 0.1053
# Epoch 1 Batch 1200 Loss 6.2197 Accuracy 0.1063
# Epoch 1 Batch 1250 Loss 6.2131 Accuracy 0.1072
# Epoch 1 Batch 1300 Loss 6.2050 Accuracy 0.1081
# Epoch 1 Batch 1350 Loss 6.1984 Accuracy 0.1090
# Epoch 1 Batch 1400 Loss 6.1913 Accuracy 0.1098
# Epoch 1 Batch 1450 Loss 6.1856 Accuracy 0.1105
# Epoch 1 Batch 1500 Loss 6.1798 Accuracy 0.1112
# Epoch 1 Batch 1550 Loss 6.1746 Accuracy 0.1117
# Epoch 1 Batch 1600 Loss 6.1693 Accuracy 0.1124
# Epoch 1 Batch 1650 Loss 6.1646 Accuracy 0.1129
# Epoch 1 Batch 1700 Loss 6.1600 Accuracy 0.1135
# Epoch 1 Batch 1750 Loss 6.1555 Accuracy 0.1140
# Epoch 1 Batch 1800 Loss 6.1526 Accuracy 0.1144
# Epoch 1 Batch 1850 Loss 6.1497 Accuracy 0.1147
# Epoch 1 Batch 1900 Loss 6.1472 Accuracy 0.1148
# Epoch 1 Batch 1950 Loss 6.1445 Accuracy 0.1150
# Epoch 1 Batch 2000 Loss 6.1406 Accuracy 0.1155
# Epoch 1 Batch 2050 Loss 6.1371 Accuracy 0.1159
# Epoch 1 Batch 2100 Loss 6.1333 Accuracy 0.1164
# Epoch 1 Batch 2150 Loss 6.1301 Accuracy 0.1168
# Epoch 1 Batch 2200 Loss 6.1268 Accuracy 0.1172
# Epoch 1 Batch 2250 Loss 6.1231 Accuracy 0.1176
# Epoch 1 Batch 2300 Loss 6.1201 Accuracy 0.1180
# Epoch 1 Batch 2350 Loss 6.1173 Accuracy 0.1183
# Epoch 1 Batch 2400 Loss 6.1152 Accuracy 0.1186
# Epoch 1 Batch 2450 Loss 6.1132 Accuracy 0.1188
# Epoch 1 Batch 2500 Loss 6.1125 Accuracy 0.1186
# Epoch 1 Batch 2550 Loss 6.1111 Accuracy 0.1186
# Epoch 1 Batch 2600 Loss 6.1100 Accuracy 0.1185
# Epoch 1 Loss 6.1092 Accuracy 0.1186
# Time taken for 1 epoch: 503.43332982063293 secs
#
# Epoch 2 Batch 0 Loss 6.0329 Accuracy 0.1200
# Epoch 2 Batch 50 Loss 6.0115 Accuracy 0.1291
# Epoch 2 Batch 100 Loss 6.0050 Accuracy 0.1299
# Epoch 2 Batch 150 Loss 5.9940 Accuracy 0.1304
# Epoch 2 Batch 200 Loss 5.9898 Accuracy 0.1308
# Epoch 2 Batch 250 Loss 5.9885 Accuracy 0.1308
# Epoch 2 Batch 300 Loss 5.9857 Accuracy 0.1312
# Epoch 2 Batch 350 Loss 5.9834 Accuracy 0.1315
# Epoch 2 Batch 400 Loss 5.9829 Accuracy 0.1310
# Epoch 2 Batch 450 Loss 5.9815 Accuracy 0.1310
# Epoch 2 Batch 500 Loss 5.9798 Accuracy 0.1310
# Epoch 2 Batch 550 Loss 5.9771 Accuracy 0.1311
# Epoch 2 Batch 600 Loss 5.9829 Accuracy 0.1300
# Epoch 2 Batch 650 Loss 6.0034 Accuracy 0.1255
# Epoch 2 Batch 700 Loss 6.0145 Accuracy 0.1224
# Epoch 2 Batch 750 Loss 6.0251 Accuracy 0.1199
# Epoch 2 Batch 800 Loss 6.0319 Accuracy 0.1178
# Epoch 2 Batch 850 Loss 6.0377 Accuracy 0.1162
# Epoch 2 Batch 900 Loss 6.0415 Accuracy 0.1147
# Epoch 2 Batch 950 Loss 6.0443 Accuracy 0.1133
# Epoch 2 Batch 1000 Loss 6.0469 Accuracy 0.1122
# Epoch 2 Batch 1050 Loss 6.0493 Accuracy 0.1111
# Epoch 2 Batch 1100 Loss 6.0509 Accuracy 0.1102
# Epoch 2 Batch 1150 Loss 6.0527 Accuracy 0.1093
# Epoch 2 Batch 1200 Loss 6.0543 Accuracy 0.1085
# Epoch 2 Batch 1250 Loss 6.0551 Accuracy 0.1079
# Epoch 2 Batch 1300 Loss 6.0572 Accuracy 0.1072
# Epoch 2 Batch 1350 Loss 6.0585 Accuracy 0.1067
# Epoch 2 Batch 1400 Loss 6.0596 Accuracy 0.1061
# Epoch 2 Batch 1450 Loss 6.0603 Accuracy 0.1056
# Epoch 2 Batch 1500 Loss 6.0608 Accuracy 0.1052
# Epoch 2 Batch 1550 Loss 6.0602 Accuracy 0.1049
# Epoch 2 Batch 1600 Loss 6.0608 Accuracy 0.1046
# Epoch 2 Batch 1650 Loss 6.0612 Accuracy 0.1043
# Epoch 2 Batch 1700 Loss 6.0616 Accuracy 0.1040
# Epoch 2 Batch 1750 Loss 6.0616 Accuracy 0.1037
# Epoch 2 Batch 1800 Loss 6.0615 Accuracy 0.1034
# Epoch 2 Batch 1850 Loss 6.0616 Accuracy 0.1032
# Epoch 2 Batch 1900 Loss 6.0622 Accuracy 0.1029
# Epoch 2 Batch 1950 Loss 6.0616 Accuracy 0.1028
# Epoch 2 Batch 2000 Loss 6.0617 Accuracy 0.1026
# Epoch 2 Batch 2050 Loss 6.0612 Accuracy 0.1024
# Epoch 2 Batch 2100 Loss 6.0610 Accuracy 0.1022
# Epoch 2 Batch 2150 Loss 6.0609 Accuracy 0.1021
# Epoch 2 Batch 2200 Loss 6.0605 Accuracy 0.1019
# Epoch 2 Batch 2250 Loss 6.0602 Accuracy 0.1018
# Epoch 2 Batch 2300 Loss 6.0600 Accuracy 0.1016
# Epoch 2 Batch 2350 Loss 6.0597 Accuracy 0.1015
# Epoch 2 Batch 2400 Loss 6.0593 Accuracy 0.1013
# Epoch 2 Batch 2450 Loss 6.0589 Accuracy 0.1012
# Epoch 2 Batch 2500 Loss 6.0603 Accuracy 0.1010
# Epoch 2 Batch 2550 Loss 6.0663 Accuracy 0.1002
# Epoch 2 Batch 2600 Loss 6.0704 Accuracy 0.0997
# Epoch 2 Loss 6.0714 Accuracy 0.0995
# Time taken for 1 epoch: 179.89841866493225 secs
#
# Epoch 3 Batch 0 Loss 6.0925 Accuracy 0.0731
# Epoch 3 Batch 50 Loss 6.1407 Accuracy 0.0834
# Epoch 3 Batch 100 Loss 6.1258 Accuracy 0.0856
# Epoch 3 Batch 150 Loss 6.1151 Accuracy 0.0868
# Epoch 3 Batch 200 Loss 6.1052 Accuracy 0.0880
# Epoch 3 Batch 250 Loss 6.0946 Accuracy 0.0887
# Epoch 3 Batch 300 Loss 6.0930 Accuracy 0.0892
# Epoch 3 Batch 350 Loss 6.0874 Accuracy 0.0896
# Epoch 3 Batch 400 Loss 6.0856 Accuracy 0.0898
# Epoch 3 Batch 450 Loss 6.0813 Accuracy 0.0902
# Epoch 3 Batch 500 Loss 6.0778 Accuracy 0.0905
# Epoch 3 Batch 550 Loss 6.0755 Accuracy 0.0908
# Epoch 3 Batch 600 Loss 6.0728 Accuracy 0.0912
# Epoch 3 Batch 650 Loss 6.0709 Accuracy 0.0914
# Epoch 3 Batch 700 Loss 6.0690 Accuracy 0.0917
# Epoch 3 Batch 750 Loss 6.0669 Accuracy 0.0919
# Epoch 3 Batch 800 Loss 6.0639 Accuracy 0.0921
# Epoch 3 Batch 850 Loss 6.0627 Accuracy 0.0923
# Epoch 3 Batch 900 Loss 6.0614 Accuracy 0.0925
# Epoch 3 Batch 950 Loss 6.0594 Accuracy 0.0927
# Epoch 3 Batch 1000 Loss 6.0582 Accuracy 0.0929
# Epoch 3 Batch 1050 Loss 6.0567 Accuracy 0.0930
# Epoch 3 Batch 1100 Loss 6.0551 Accuracy 0.0932
# Epoch 3 Batch 1150 Loss 6.0540 Accuracy 0.0933
# Epoch 3 Batch 1200 Loss 6.0529 Accuracy 0.0935
# Epoch 3 Batch 1250 Loss 6.0518 Accuracy 0.0937
# Epoch 3 Batch 1300 Loss 6.0505 Accuracy 0.0938
# Epoch 3 Batch 1350 Loss 6.0490 Accuracy 0.0939
# Epoch 3 Batch 1400 Loss 6.0484 Accuracy 0.0940
# Epoch 3 Batch 1450 Loss 6.0478 Accuracy 0.0941
# Epoch 3 Batch 1500 Loss 6.0465 Accuracy 0.0942
# Epoch 3 Batch 1550 Loss 6.0455 Accuracy 0.0943
# Epoch 3 Batch 1600 Loss 6.0438 Accuracy 0.0944
# Epoch 3 Batch 1650 Loss 6.0428 Accuracy 0.0946
# Epoch 3 Batch 1700 Loss 6.0440 Accuracy 0.0945
# Epoch 3 Batch 1750 Loss 6.0477 Accuracy 0.0943
# Epoch 3 Batch 1800 Loss 6.0501 Accuracy 0.0941
# Epoch 3 Batch 1850 Loss 6.0513 Accuracy 0.0941
# Epoch 3 Batch 1900 Loss 6.0518 Accuracy 0.0941
# Epoch 3 Batch 1950 Loss 6.0519 Accuracy 0.0940
# Epoch 3 Batch 2000 Loss 6.0515 Accuracy 0.0941
# Epoch 3 Batch 2050 Loss 6.0513 Accuracy 0.0941
# Epoch 3 Batch 2100 Loss 6.0512 Accuracy 0.0942
# Epoch 3 Batch 2150 Loss 6.0512 Accuracy 0.0942
# Epoch 3 Batch 2200 Loss 6.0509 Accuracy 0.0943
# Epoch 3 Batch 2250 Loss 6.0507 Accuracy 0.0943
# Epoch 3 Batch 2300 Loss 6.0503 Accuracy 0.0943
# Epoch 3 Batch 2350 Loss 6.0496 Accuracy 0.0944
# Epoch 3 Batch 2400 Loss 6.0490 Accuracy 0.0944
# Epoch 3 Batch 2450 Loss 6.0485 Accuracy 0.0945
# Epoch 3 Batch 2500 Loss 6.0476 Accuracy 0.0945
# Epoch 3 Batch 2550 Loss 6.0467 Accuracy 0.0946
# Epoch 3 Batch 2600 Loss 6.0463 Accuracy 0.0946
# Epoch 3 Loss 6.0458 Accuracy 0.0947
# Time taken for 1 epoch: 174.33346819877625 secs
#
# Epoch 4 Batch 0 Loss 5.8709 Accuracy 0.1124
# Epoch 4 Batch 50 Loss 5.9980 Accuracy 0.0972
# Epoch 4 Batch 100 Loss 6.0135 Accuracy 0.0968
# Epoch 4 Batch 150 Loss 6.0139 Accuracy 0.0963
# Epoch 4 Batch 200 Loss 6.0124 Accuracy 0.0967
# Epoch 4 Batch 250 Loss 6.0083 Accuracy 0.0971
# Epoch 4 Batch 300 Loss 6.0089 Accuracy 0.0970
# Epoch 4 Batch 350 Loss 6.0087 Accuracy 0.0972
# Epoch 4 Batch 400 Loss 6.0065 Accuracy 0.0973
# Epoch 4 Batch 450 Loss 6.0031 Accuracy 0.0975
# Epoch 4 Batch 500 Loss 6.0004 Accuracy 0.0977
# Epoch 4 Batch 550 Loss 5.9998 Accuracy 0.0979
# Epoch 4 Batch 600 Loss 5.9991 Accuracy 0.0980
# Epoch 4 Batch 650 Loss 5.9978 Accuracy 0.0980
# Epoch 4 Batch 700 Loss 5.9967 Accuracy 0.0980
# Epoch 4 Batch 750 Loss 5.9949 Accuracy 0.0980
# Epoch 4 Batch 800 Loss 5.9948 Accuracy 0.0981
# Epoch 4 Batch 850 Loss 5.9943 Accuracy 0.0982
# Epoch 4 Batch 900 Loss 5.9948 Accuracy 0.0982
# Epoch 4 Batch 950 Loss 5.9948 Accuracy 0.0982
# Epoch 4 Batch 1000 Loss 5.9942 Accuracy 0.0981
# Epoch 4 Batch 1050 Loss 5.9934 Accuracy 0.0982
# Epoch 4 Batch 1100 Loss 5.9938 Accuracy 0.0981
# Epoch 4 Batch 1150 Loss 5.9933 Accuracy 0.0983
# Epoch 4 Batch 1200 Loss 5.9920 Accuracy 0.0984
# Epoch 4 Batch 1250 Loss 5.9922 Accuracy 0.0984
# Epoch 4 Batch 1300 Loss 5.9914 Accuracy 0.0984
# Epoch 4 Batch 1350 Loss 5.9908 Accuracy 0.0984
# Epoch 4 Batch 1400 Loss 5.9898 Accuracy 0.0985
# Epoch 4 Batch 1450 Loss 5.9907 Accuracy 0.0984
# Epoch 4 Batch 1500 Loss 5.9908 Accuracy 0.0985
# Epoch 4 Batch 1550 Loss 5.9910 Accuracy 0.0985
# Epoch 4 Batch 1600 Loss 5.9903 Accuracy 0.0986
# Epoch 4 Batch 1650 Loss 5.9894 Accuracy 0.0987
# Epoch 4 Batch 1700 Loss 5.9891 Accuracy 0.0987
# Epoch 4 Batch 1750 Loss 5.9889 Accuracy 0.0988
# Epoch 4 Batch 1800 Loss 5.9890 Accuracy 0.0988
# Epoch 4 Batch 1850 Loss 5.9886 Accuracy 0.0989
# Epoch 4 Batch 1900 Loss 5.9883 Accuracy 0.0989
# Epoch 4 Batch 1950 Loss 5.9881 Accuracy 0.0989
# Epoch 4 Batch 2000 Loss 5.9876 Accuracy 0.0990
# Epoch 4 Batch 2050 Loss 5.9871 Accuracy 0.0990
# Epoch 4 Batch 2100 Loss 5.9863 Accuracy 0.0991
# Epoch 4 Batch 2150 Loss 5.9856 Accuracy 0.0992
# Epoch 4 Batch 2200 Loss 5.9850 Accuracy 0.0992
# Epoch 4 Batch 2250 Loss 5.9845 Accuracy 0.0992
# Epoch 4 Batch 2300 Loss 5.9838 Accuracy 0.0993
# Epoch 4 Batch 2350 Loss 5.9836 Accuracy 0.0993
# Epoch 4 Batch 2400 Loss 5.9836 Accuracy 0.0993
# Epoch 4 Batch 2450 Loss 5.9833 Accuracy 0.0994
# Epoch 4 Batch 2500 Loss 5.9826 Accuracy 0.0994
# Epoch 4 Batch 2550 Loss 5.9823 Accuracy 0.0994
# Epoch 4 Batch 2600 Loss 5.9830 Accuracy 0.0994
# Epoch 4 Loss 5.9848 Accuracy 0.0993
# Time taken for 1 epoch: 173.62077140808105 secs
#
# Epoch 5 Batch 0 Loss 6.0220 Accuracy 0.0942
# Epoch 5 Batch 50 Loss 6.0265 Accuracy 0.1021
# Epoch 5 Batch 100 Loss 6.0247 Accuracy 0.1012
# Epoch 5 Batch 150 Loss 6.0725 Accuracy 0.0979
# Epoch 5 Batch 200 Loss 6.1230 Accuracy 0.0928
# Epoch 5 Batch 250 Loss 6.1552 Accuracy 0.0897
# Epoch 5 Batch 300 Loss 6.1663 Accuracy 0.0889
# Epoch 5 Batch 350 Loss 6.1757 Accuracy 0.0882
# Epoch 5 Batch 400 Loss 6.1780 Accuracy 0.0883
# Epoch 5 Batch 450 Loss 6.1780 Accuracy 0.0888
# Epoch 5 Batch 500 Loss 6.1742 Accuracy 0.0899
# Epoch 5 Batch 550 Loss 6.1763 Accuracy 0.0897
# Epoch 5 Batch 600 Loss 6.1658 Accuracy 0.0924
# Epoch 5 Batch 650 Loss 6.1574 Accuracy 0.0947
# Epoch 5 Batch 700 Loss 6.1496 Accuracy 0.0968
# Epoch 5 Batch 750 Loss 6.1433 Accuracy 0.0986
# Epoch 5 Batch 800 Loss 6.1370 Accuracy 0.1004
# Epoch 5 Batch 850 Loss 6.1310 Accuracy 0.1019
# Epoch 5 Batch 900 Loss 6.1258 Accuracy 0.1031
# Epoch 5 Batch 950 Loss 6.1255 Accuracy 0.1033
# Epoch 5 Batch 1000 Loss 6.1280 Accuracy 0.1024
# Epoch 5 Batch 1050 Loss 6.1309 Accuracy 0.1015
# Epoch 5 Batch 1100 Loss 6.1331 Accuracy 0.1008
# Epoch 5 Batch 1150 Loss 6.1344 Accuracy 0.1002
# Epoch 5 Batch 1200 Loss 6.1351 Accuracy 0.0997
# Epoch 5 Batch 1250 Loss 6.1352 Accuracy 0.0992
# Epoch 5 Batch 1300 Loss 6.1360 Accuracy 0.0989
# Epoch 5 Batch 1350 Loss 6.1357 Accuracy 0.0986
# Epoch 5 Batch 1400 Loss 6.1350 Accuracy 0.0982
# Epoch 5 Batch 1450 Loss 6.1337 Accuracy 0.0979
# Epoch 5 Batch 1500 Loss 6.1325 Accuracy 0.0977
# Epoch 5 Batch 1550 Loss 6.1320 Accuracy 0.0974
# Epoch 5 Batch 1600 Loss 6.1310 Accuracy 0.0971
# Epoch 5 Batch 1650 Loss 6.1301 Accuracy 0.0970
# Epoch 5 Batch 1700 Loss 6.1288 Accuracy 0.0968
# Epoch 5 Batch 1750 Loss 6.1276 Accuracy 0.0967
# Epoch 5 Batch 1800 Loss 6.1267 Accuracy 0.0966
# Epoch 5 Batch 1850 Loss 6.1258 Accuracy 0.0965
# Epoch 5 Batch 1900 Loss 6.1252 Accuracy 0.0963
# Epoch 5 Batch 1950 Loss 6.1238 Accuracy 0.0962
# Epoch 5 Batch 2000 Loss 6.1231 Accuracy 0.0961
# Epoch 5 Batch 2050 Loss 6.1219 Accuracy 0.0960
# Epoch 5 Batch 2100 Loss 6.1206 Accuracy 0.0959
# Epoch 5 Batch 2150 Loss 6.1198 Accuracy 0.0958
# Epoch 5 Batch 2200 Loss 6.1186 Accuracy 0.0957
# Epoch 5 Batch 2250 Loss 6.1181 Accuracy 0.0956
# Epoch 5 Batch 2300 Loss 6.1168 Accuracy 0.0956
# Epoch 5 Batch 2350 Loss 6.1158 Accuracy 0.0955
# Epoch 5 Batch 2400 Loss 6.1151 Accuracy 0.0954
# Epoch 5 Batch 2450 Loss 6.1142 Accuracy 0.0954
# Epoch 5 Batch 2500 Loss 6.1134 Accuracy 0.0953
# Epoch 5 Batch 2550 Loss 6.1125 Accuracy 0.0952
# Epoch 5 Batch 2600 Loss 6.1119 Accuracy 0.0952
# Saving checkpoint for epoch 5 at ./checkpoints/train/ckpt-1
# Epoch 5 Loss 6.1113 Accuracy 0.0952
# Time taken for 1 epoch: 176.45922350883484 secs
#
# Epoch 6 Batch 0 Loss 6.0074 Accuracy 0.0832
# Epoch 6 Batch 50 Loss 6.0607 Accuracy 0.0931
# Epoch 6 Batch 100 Loss 6.0506 Accuracy 0.0924
# Epoch 6 Batch 150 Loss 6.0532 Accuracy 0.0922
# Epoch 6 Batch 200 Loss 6.0574 Accuracy 0.0925
# Epoch 6 Batch 250 Loss 6.0537 Accuracy 0.0925
# Epoch 6 Batch 300 Loss 6.0521 Accuracy 0.0928
# Epoch 6 Batch 350 Loss 6.0503 Accuracy 0.0929
# Epoch 6 Batch 400 Loss 6.0512 Accuracy 0.0929
# Epoch 6 Batch 450 Loss 6.0508 Accuracy 0.0933
# Epoch 6 Batch 500 Loss 6.0517 Accuracy 0.0932
# Epoch 6 Batch 550 Loss 6.0512 Accuracy 0.0933
# Epoch 6 Batch 600 Loss 6.0521 Accuracy 0.0931
# Epoch 6 Batch 650 Loss 6.0525 Accuracy 0.0931
# Epoch 6 Batch 700 Loss 6.0527 Accuracy 0.0931
# Epoch 6 Batch 750 Loss 6.0528 Accuracy 0.0931
# Epoch 6 Batch 800 Loss 6.0520 Accuracy 0.0933
# Epoch 6 Batch 850 Loss 6.0523 Accuracy 0.0933
# Epoch 6 Batch 900 Loss 6.0522 Accuracy 0.0932
# Epoch 6 Batch 950 Loss 6.0521 Accuracy 0.0933
# Epoch 6 Batch 1000 Loss 6.0514 Accuracy 0.0933
# Epoch 6 Batch 1050 Loss 6.0507 Accuracy 0.0934
# Epoch 6 Batch 1100 Loss 6.0494 Accuracy 0.0935
# Epoch 6 Batch 1150 Loss 6.0481 Accuracy 0.0935
# Epoch 6 Batch 1200 Loss 6.0471 Accuracy 0.0936
# Epoch 6 Batch 1250 Loss 6.0458 Accuracy 0.0937
# Epoch 6 Batch 1300 Loss 6.0455 Accuracy 0.0938
# Epoch 6 Batch 1350 Loss 6.0463 Accuracy 0.0938
# Epoch 6 Batch 1400 Loss 6.0461 Accuracy 0.0938
# Epoch 6 Batch 1450 Loss 6.0459 Accuracy 0.0938
# Epoch 6 Batch 1500 Loss 6.0450 Accuracy 0.0939
# Epoch 6 Batch 1550 Loss 6.0445 Accuracy 0.0939
# Epoch 6 Batch 1600 Loss 6.0436 Accuracy 0.0940
# Epoch 6 Batch 1650 Loss 6.0435 Accuracy 0.0940
# Epoch 6 Batch 1700 Loss 6.0424 Accuracy 0.0941
# Epoch 6 Batch 1750 Loss 6.0415 Accuracy 0.0941
# Epoch 6 Batch 1800 Loss 6.0416 Accuracy 0.0941
# Epoch 6 Batch 1850 Loss 6.0413 Accuracy 0.0941
# Epoch 6 Batch 1900 Loss 6.0408 Accuracy 0.0941
# Epoch 6 Batch 1950 Loss 6.0404 Accuracy 0.0942
# Epoch 6 Batch 2000 Loss 6.0406 Accuracy 0.0942
# Epoch 6 Batch 2050 Loss 6.0401 Accuracy 0.0943
# Epoch 6 Batch 2100 Loss 6.0395 Accuracy 0.0944
# Epoch 6 Batch 2150 Loss 6.0388 Accuracy 0.0944
# Epoch 6 Batch 2200 Loss 6.0385 Accuracy 0.0944
# Epoch 6 Batch 2250 Loss 6.0380 Accuracy 0.0945
# Epoch 6 Batch 2300 Loss 6.0376 Accuracy 0.0945
# Epoch 6 Batch 2350 Loss 6.0371 Accuracy 0.0946
# Epoch 6 Batch 2400 Loss 6.0368 Accuracy 0.0946
# Epoch 6 Batch 2450 Loss 6.0363 Accuracy 0.0946
# Epoch 6 Batch 2500 Loss 6.0358 Accuracy 0.0946
# Epoch 6 Batch 2550 Loss 6.0358 Accuracy 0.0946
# Epoch 6 Batch 2600 Loss 6.0350 Accuracy 0.0946
# Epoch 6 Loss 6.0349 Accuracy 0.0946
# Time taken for 1 epoch: 176.53444385528564 secs
#
# Epoch 7 Batch 0 Loss 6.1189 Accuracy 0.0940
# Epoch 7 Batch 50 Loss 5.9955 Accuracy 0.0973
# Epoch 7 Batch 100 Loss 6.0080 Accuracy 0.0955
# Epoch 7 Batch 150 Loss 6.0076 Accuracy 0.0954
# Epoch 7 Batch 200 Loss 6.0098 Accuracy 0.0955
# Epoch 7 Batch 250 Loss 6.0116 Accuracy 0.0956
# Epoch 7 Batch 300 Loss 6.0160 Accuracy 0.0955
# Epoch 7 Batch 350 Loss 6.0146 Accuracy 0.0954
# Epoch 7 Batch 400 Loss 6.0142 Accuracy 0.0954
# Epoch 7 Batch 450 Loss 6.0133 Accuracy 0.0958
# Epoch 7 Batch 500 Loss 6.0119 Accuracy 0.0959
# Epoch 7 Batch 550 Loss 6.0122 Accuracy 0.0960
# Epoch 7 Batch 600 Loss 6.0109 Accuracy 0.0959
# Epoch 7 Batch 650 Loss 6.0106 Accuracy 0.0960
# Epoch 7 Batch 700 Loss 6.0100 Accuracy 0.0960
# Epoch 7 Batch 750 Loss 6.0097 Accuracy 0.0961
# Epoch 7 Batch 800 Loss 6.0084 Accuracy 0.0962
# Epoch 7 Batch 850 Loss 6.0076 Accuracy 0.0962
# Epoch 7 Batch 900 Loss 6.0071 Accuracy 0.0962
# Epoch 7 Batch 950 Loss 6.0064 Accuracy 0.0963
# Epoch 7 Batch 1000 Loss 6.0053 Accuracy 0.0963
# Epoch 7 Batch 1050 Loss 6.0045 Accuracy 0.0963
# Epoch 7 Batch 1100 Loss 6.0051 Accuracy 0.0962
# Epoch 7 Batch 1150 Loss 6.0054 Accuracy 0.0962
# Epoch 7 Batch 1200 Loss 6.0052 Accuracy 0.0962
# Epoch 7 Batch 1250 Loss 6.0050 Accuracy 0.0962
# Epoch 7 Batch 1300 Loss 6.0048 Accuracy 0.0962
# Epoch 7 Batch 1350 Loss 6.0043 Accuracy 0.0963
# Epoch 7 Batch 1400 Loss 6.0051 Accuracy 0.0962
# Epoch 7 Batch 1450 Loss 6.0050 Accuracy 0.0963
# Epoch 7 Batch 1500 Loss 6.0053 Accuracy 0.0962
# Epoch 7 Batch 1550 Loss 6.0052 Accuracy 0.0963
# Epoch 7 Batch 1600 Loss 6.0047 Accuracy 0.0963
# Epoch 7 Batch 1650 Loss 6.0042 Accuracy 0.0964
# Epoch 7 Batch 1700 Loss 6.0045 Accuracy 0.0964
# Epoch 7 Batch 1750 Loss 6.0042 Accuracy 0.0965
# Epoch 7 Batch 1800 Loss 6.0040 Accuracy 0.0965
# Epoch 7 Batch 1850 Loss 6.0034 Accuracy 0.0965
# Epoch 7 Batch 1900 Loss 6.0031 Accuracy 0.0966
# Epoch 7 Batch 1950 Loss 6.0025 Accuracy 0.0966
# Epoch 7 Batch 2000 Loss 6.0020 Accuracy 0.0966
# Epoch 7 Batch 2050 Loss 6.0021 Accuracy 0.0966
# Epoch 7 Batch 2100 Loss 6.0019 Accuracy 0.0966
# Epoch 7 Batch 2150 Loss 6.0018 Accuracy 0.0966
# Epoch 7 Batch 2200 Loss 6.0014 Accuracy 0.0967
# Epoch 7 Batch 2250 Loss 6.0012 Accuracy 0.0967
# Epoch 7 Batch 2300 Loss 6.0007 Accuracy 0.0967
# Epoch 7 Batch 2350 Loss 6.0005 Accuracy 0.0968
# Epoch 7 Batch 2400 Loss 6.0006 Accuracy 0.0968
# Epoch 7 Batch 2450 Loss 6.0003 Accuracy 0.0968
# Epoch 7 Batch 2500 Loss 6.0000 Accuracy 0.0968
# Epoch 7 Batch 2550 Loss 5.9996 Accuracy 0.0969
# Epoch 7 Batch 2600 Loss 5.9992 Accuracy 0.0969
# Epoch 7 Loss 5.9989 Accuracy 0.0969
# Time taken for 1 epoch: 175.75424909591675 secs
#
# Epoch 8 Batch 0 Loss 6.1477 Accuracy 0.0990
# Epoch 8 Batch 50 Loss 5.9846 Accuracy 0.0983
# Epoch 8 Batch 100 Loss 5.9862 Accuracy 0.0979
# Epoch 8 Batch 150 Loss 5.9848 Accuracy 0.0982
# Epoch 8 Batch 200 Loss 5.9815 Accuracy 0.0978
# Epoch 8 Batch 250 Loss 5.9820 Accuracy 0.0975
# Epoch 8 Batch 300 Loss 5.9775 Accuracy 0.0979
# Epoch 8 Batch 350 Loss 5.9784 Accuracy 0.0980
# Epoch 8 Batch 400 Loss 5.9795 Accuracy 0.0981
# Epoch 8 Batch 450 Loss 5.9794 Accuracy 0.0982
# Epoch 8 Batch 500 Loss 5.9792 Accuracy 0.0982
# Epoch 8 Batch 550 Loss 5.9788 Accuracy 0.0982
# Epoch 8 Batch 600 Loss 5.9793 Accuracy 0.0982
# Epoch 8 Batch 650 Loss 5.9780 Accuracy 0.0982
# Epoch 8 Batch 700 Loss 5.9793 Accuracy 0.0982
# Epoch 8 Batch 750 Loss 5.9802 Accuracy 0.0981
# Epoch 8 Batch 800 Loss 5.9795 Accuracy 0.0981
# Epoch 8 Batch 850 Loss 5.9794 Accuracy 0.0980
# Epoch 8 Batch 900 Loss 5.9781 Accuracy 0.0982
# Epoch 8 Batch 950 Loss 5.9785 Accuracy 0.0981
# Epoch 8 Batch 1000 Loss 5.9783 Accuracy 0.0982
# Epoch 8 Batch 1050 Loss 5.9788 Accuracy 0.0982
# Epoch 8 Batch 1100 Loss 5.9798 Accuracy 0.0982
# Epoch 8 Batch 1150 Loss 5.9808 Accuracy 0.0982
# Epoch 8 Batch 1200 Loss 5.9813 Accuracy 0.0982
# Epoch 8 Batch 1250 Loss 5.9814 Accuracy 0.0982
# Epoch 8 Batch 1300 Loss 5.9807 Accuracy 0.0982
# Epoch 8 Batch 1350 Loss 5.9813 Accuracy 0.0983
# Epoch 8 Batch 1400 Loss 5.9807 Accuracy 0.0983
# Epoch 8 Batch 1450 Loss 5.9804 Accuracy 0.0983
# Epoch 8 Batch 1500 Loss 5.9808 Accuracy 0.0983
# Epoch 8 Batch 1550 Loss 5.9812 Accuracy 0.0983
# Epoch 8 Batch 1600 Loss 5.9812 Accuracy 0.0983
# Epoch 8 Batch 1650 Loss 5.9815 Accuracy 0.0984
# Epoch 8 Batch 1700 Loss 5.9820 Accuracy 0.0983
# Epoch 8 Batch 1750 Loss 5.9826 Accuracy 0.0983
# Epoch 8 Batch 1800 Loss 5.9823 Accuracy 0.0983
# Epoch 8 Batch 1850 Loss 5.9827 Accuracy 0.0983
# Epoch 8 Batch 1900 Loss 5.9828 Accuracy 0.0983
# Epoch 8 Batch 1950 Loss 5.9827 Accuracy 0.0983
# Epoch 8 Batch 2000 Loss 5.9828 Accuracy 0.0983
# Epoch 8 Batch 2050 Loss 5.9829 Accuracy 0.0983
# Epoch 8 Batch 2100 Loss 5.9823 Accuracy 0.0983
# Epoch 8 Batch 2150 Loss 5.9818 Accuracy 0.0983
# Epoch 8 Batch 2200 Loss 5.9819 Accuracy 0.0984
# Epoch 8 Batch 2250 Loss 5.9816 Accuracy 0.0984
# Epoch 8 Batch 2300 Loss 5.9818 Accuracy 0.0984
# Epoch 8 Batch 2350 Loss 5.9814 Accuracy 0.0984
# Epoch 8 Batch 2400 Loss 5.9809 Accuracy 0.0984
# Epoch 8 Batch 2450 Loss 5.9807 Accuracy 0.0985
# Epoch 8 Batch 2500 Loss 5.9809 Accuracy 0.0984
# Epoch 8 Batch 2550 Loss 5.9810 Accuracy 0.0984
# Epoch 8 Batch 2600 Loss 5.9812 Accuracy 0.0984
# Epoch 8 Loss 5.9813 Accuracy 0.0984
# Time taken for 1 epoch: 176.86123204231262 secs
#
# Epoch 9 Batch 0 Loss 6.0044 Accuracy 0.1007
# Epoch 9 Batch 50 Loss 5.9728 Accuracy 0.0992
# Epoch 9 Batch 100 Loss 5.9836 Accuracy 0.0970
# Epoch 9 Batch 150 Loss 5.9888 Accuracy 0.0971
# Epoch 9 Batch 200 Loss 5.9871 Accuracy 0.0974
# Epoch 9 Batch 250 Loss 5.9812 Accuracy 0.0978
# Epoch 9 Batch 300 Loss 5.9783 Accuracy 0.0982
# Epoch 9 Batch 350 Loss 5.9780 Accuracy 0.0988
# Epoch 9 Batch 400 Loss 5.9773 Accuracy 0.1003
# Epoch 9 Batch 450 Loss 5.9771 Accuracy 0.0999
# Epoch 9 Batch 500 Loss 5.9776 Accuracy 0.0997
# Epoch 9 Batch 550 Loss 5.9782 Accuracy 0.0994
# Epoch 9 Batch 600 Loss 5.9780 Accuracy 0.0993
# Epoch 9 Batch 650 Loss 5.9764 Accuracy 0.0992
# Epoch 9 Batch 700 Loss 5.9745 Accuracy 0.0992
# Epoch 9 Batch 750 Loss 5.9748 Accuracy 0.0991
# Epoch 9 Batch 800 Loss 5.9751 Accuracy 0.0992
# Epoch 9 Batch 850 Loss 5.9747 Accuracy 0.0992
# Epoch 9 Batch 900 Loss 5.9748 Accuracy 0.0993
# Epoch 9 Batch 950 Loss 5.9753 Accuracy 0.0991
# Epoch 9 Batch 1000 Loss 5.9750 Accuracy 0.0992
# Epoch 9 Batch 1050 Loss 5.9764 Accuracy 0.0990
# Epoch 9 Batch 1100 Loss 5.9763 Accuracy 0.0991
# Epoch 9 Batch 1150 Loss 5.9760 Accuracy 0.0991
# Epoch 9 Batch 1200 Loss 5.9749 Accuracy 0.0991
# Epoch 9 Batch 1250 Loss 5.9743 Accuracy 0.0991
# Epoch 9 Batch 1300 Loss 5.9741 Accuracy 0.0992
# Epoch 9 Batch 1350 Loss 5.9735 Accuracy 0.0992
# Epoch 9 Batch 1400 Loss 5.9733 Accuracy 0.0992
# Epoch 9 Batch 1450 Loss 5.9730 Accuracy 0.0992
# Epoch 9 Batch 1500 Loss 5.9737 Accuracy 0.0992
# Epoch 9 Batch 1550 Loss 5.9742 Accuracy 0.0992
# Epoch 9 Batch 1600 Loss 5.9737 Accuracy 0.0993
# Epoch 9 Batch 1650 Loss 5.9738 Accuracy 0.0994
# Epoch 9 Batch 1700 Loss 5.9743 Accuracy 0.0993
# Epoch 9 Batch 1750 Loss 5.9737 Accuracy 0.0993
# Epoch 9 Batch 1800 Loss 5.9731 Accuracy 0.0994
# Epoch 9 Batch 1850 Loss 5.9736 Accuracy 0.0994
# Epoch 9 Batch 1900 Loss 5.9740 Accuracy 0.0994
# Epoch 9 Batch 1950 Loss 5.9740 Accuracy 0.0994
# Epoch 9 Batch 2000 Loss 5.9741 Accuracy 0.0994
# Epoch 9 Batch 2050 Loss 5.9735 Accuracy 0.0996
# Epoch 9 Batch 2100 Loss 5.9740 Accuracy 0.0999
# Epoch 9 Batch 2150 Loss 5.9762 Accuracy 0.1003
# Epoch 9 Batch 2200 Loss 5.9752 Accuracy 0.1012
# Epoch 9 Batch 2250 Loss 5.9742 Accuracy 0.1021
# Epoch 9 Batch 2300 Loss 5.9727 Accuracy 0.1030
# Epoch 9 Batch 2350 Loss 5.9714 Accuracy 0.1038
# Epoch 9 Batch 2400 Loss 5.9695 Accuracy 0.1046
# Epoch 9 Batch 2450 Loss 5.9675 Accuracy 0.1055
# Epoch 9 Batch 2500 Loss 5.9658 Accuracy 0.1062
# Epoch 9 Batch 2550 Loss 5.9635 Accuracy 0.1070
# Epoch 9 Batch 2600 Loss 5.9615 Accuracy 0.1077
# Epoch 9 Loss 5.9606 Accuracy 0.1080
# Time taken for 1 epoch: 175.37237119674683 secs
#
# Epoch 10 Batch 0 Loss 5.8266 Accuracy 0.1255
# Epoch 10 Batch 50 Loss 5.8567 Accuracy 0.1444
# Epoch 10 Batch 100 Loss 5.8471 Accuracy 0.1447
# Epoch 10 Batch 150 Loss 5.8525 Accuracy 0.1446
# Epoch 10 Batch 200 Loss 5.8501 Accuracy 0.1442
# Epoch 10 Batch 250 Loss 5.8499 Accuracy 0.1438
# Epoch 10 Batch 300 Loss 5.8468 Accuracy 0.1437
# Epoch 10 Batch 350 Loss 5.8433 Accuracy 0.1439
# Epoch 10 Batch 400 Loss 5.8419 Accuracy 0.1439
# Epoch 10 Batch 450 Loss 5.8416 Accuracy 0.1439
# Epoch 10 Batch 500 Loss 5.8399 Accuracy 0.1439
# Epoch 10 Batch 550 Loss 5.8389 Accuracy 0.1441
# Epoch 10 Batch 600 Loss 5.8381 Accuracy 0.1441
# Epoch 10 Batch 650 Loss 5.8369 Accuracy 0.1441
# Epoch 10 Batch 700 Loss 5.8363 Accuracy 0.1442
# Epoch 10 Batch 750 Loss 5.8372 Accuracy 0.1441
# Epoch 10 Batch 800 Loss 5.8365 Accuracy 0.1442
# Epoch 10 Batch 850 Loss 5.8360 Accuracy 0.1440
# Epoch 10 Batch 900 Loss 5.8354 Accuracy 0.1441
# Epoch 10 Batch 950 Loss 5.8346 Accuracy 0.1440
# Epoch 10 Batch 1000 Loss 5.8345 Accuracy 0.1440
# Epoch 10 Batch 1050 Loss 5.8336 Accuracy 0.1440
# Epoch 10 Batch 1100 Loss 5.8319 Accuracy 0.1442
# Epoch 10 Batch 1150 Loss 5.8315 Accuracy 0.1442
# Epoch 10 Batch 1200 Loss 5.8300 Accuracy 0.1442
# Epoch 10 Batch 1250 Loss 5.8291 Accuracy 0.1443
# Epoch 10 Batch 1300 Loss 5.8291 Accuracy 0.1444
# Epoch 10 Batch 1350 Loss 5.8290 Accuracy 0.1443
# Epoch 10 Batch 1400 Loss 5.8285 Accuracy 0.1443
# Epoch 10 Batch 1450 Loss 5.8280 Accuracy 0.1444
# Epoch 10 Batch 1500 Loss 5.8277 Accuracy 0.1444
# Epoch 10 Batch 1550 Loss 5.8273 Accuracy 0.1444
# Epoch 10 Batch 1600 Loss 5.8274 Accuracy 0.1445
# Epoch 10 Batch 1650 Loss 5.8265 Accuracy 0.1446
# Epoch 10 Batch 1700 Loss 5.8263 Accuracy 0.1447
# Epoch 10 Batch 1750 Loss 5.8252 Accuracy 0.1447
# Epoch 10 Batch 1800 Loss 5.8249 Accuracy 0.1448
# Epoch 10 Batch 1850 Loss 5.8241 Accuracy 0.1448
# Epoch 10 Batch 1900 Loss 5.8234 Accuracy 0.1449
# Epoch 10 Batch 1950 Loss 5.8230 Accuracy 0.1449
# Epoch 10 Batch 2000 Loss 5.8231 Accuracy 0.1449
# Epoch 10 Batch 2050 Loss 5.8227 Accuracy 0.1450
# Epoch 10 Batch 2100 Loss 5.8220 Accuracy 0.1450
# Epoch 10 Batch 2150 Loss 5.8224 Accuracy 0.1450
# Epoch 10 Batch 2200 Loss 5.8221 Accuracy 0.1450
# Epoch 10 Batch 2250 Loss 5.8213 Accuracy 0.1451
# Epoch 10 Batch 2300 Loss 5.8218 Accuracy 0.1451
# Epoch 10 Batch 2350 Loss 5.8215 Accuracy 0.1451
# Epoch 10 Batch 2400 Loss 5.8209 Accuracy 0.1451
# Epoch 10 Batch 2450 Loss 5.8206 Accuracy 0.1451
# Epoch 10 Batch 2500 Loss 5.8201 Accuracy 0.1451
# Epoch 10 Batch 2550 Loss 5.8198 Accuracy 0.1452
# Epoch 10 Batch 2600 Loss 5.8197 Accuracy 0.1452
# Saving checkpoint for epoch 10 at ./checkpoints/train/ckpt-2
# Epoch 10 Loss 5.8198 Accuracy 0.1452
# Time taken for 1 epoch: 173.8652744293213 secs
#
# Epoch 11 Batch 0 Loss 5.8442 Accuracy 0.1394
# Epoch 11 Batch 50 Loss 5.8132 Accuracy 0.1463
# Epoch 11 Batch 100 Loss 5.8077 Accuracy 0.1461
# Epoch 11 Batch 150 Loss 5.8044 Accuracy 0.1453
# Epoch 11 Batch 200 Loss 5.8101 Accuracy 0.1452
# Epoch 11 Batch 250 Loss 5.8098 Accuracy 0.1452
# Epoch 11 Batch 300 Loss 5.8112 Accuracy 0.1451
# Epoch 11 Batch 350 Loss 5.8104 Accuracy 0.1450
# Epoch 11 Batch 400 Loss 5.8052 Accuracy 0.1453
# Epoch 11 Batch 450 Loss 5.8041 Accuracy 0.1454
# Epoch 11 Batch 500 Loss 5.8062 Accuracy 0.1454
# Epoch 11 Batch 550 Loss 5.8064 Accuracy 0.1453
# Epoch 11 Batch 600 Loss 5.8049 Accuracy 0.1455
# Epoch 11 Batch 650 Loss 5.8034 Accuracy 0.1456
# Epoch 11 Batch 700 Loss 5.8058 Accuracy 0.1454
# Epoch 11 Batch 750 Loss 5.8054 Accuracy 0.1454
# Epoch 11 Batch 800 Loss 5.8042 Accuracy 0.1456
# Epoch 11 Batch 850 Loss 5.8048 Accuracy 0.1457
# Epoch 11 Batch 900 Loss 5.8046 Accuracy 0.1456
# Epoch 11 Batch 950 Loss 5.8057 Accuracy 0.1455
# Epoch 11 Batch 1000 Loss 5.8044 Accuracy 0.1457
# Epoch 11 Batch 1050 Loss 5.8036 Accuracy 0.1458
# Epoch 11 Batch 1100 Loss 5.8043 Accuracy 0.1457
# Epoch 11 Batch 1150 Loss 5.8042 Accuracy 0.1457
# Epoch 11 Batch 1200 Loss 5.8042 Accuracy 0.1458
# Epoch 11 Batch 1250 Loss 5.8048 Accuracy 0.1458
# Epoch 11 Batch 1300 Loss 5.8032 Accuracy 0.1459
# Epoch 11 Batch 1350 Loss 5.8032 Accuracy 0.1459
# Epoch 11 Batch 1400 Loss 5.8034 Accuracy 0.1459
# Epoch 11 Batch 1450 Loss 5.8037 Accuracy 0.1459
# Epoch 11 Batch 1500 Loss 5.8033 Accuracy 0.1459
# Epoch 11 Batch 1550 Loss 5.8025 Accuracy 0.1459
# Epoch 11 Batch 1600 Loss 5.8021 Accuracy 0.1460
# Epoch 11 Batch 1650 Loss 5.8023 Accuracy 0.1460
# Epoch 11 Batch 1700 Loss 5.8028 Accuracy 0.1460
# Epoch 11 Batch 1750 Loss 5.8028 Accuracy 0.1460
# Epoch 11 Batch 1800 Loss 5.8030 Accuracy 0.1460
# Epoch 11 Batch 1850 Loss 5.8031 Accuracy 0.1461
# Epoch 11 Batch 1900 Loss 5.8033 Accuracy 0.1460
# Epoch 11 Batch 1950 Loss 5.8047 Accuracy 0.1460
# Epoch 11 Batch 2000 Loss 5.8066 Accuracy 0.1459
# Epoch 11 Batch 2050 Loss 5.8080 Accuracy 0.1458
# Epoch 11 Batch 2100 Loss 5.8081 Accuracy 0.1458
# Epoch 11 Batch 2150 Loss 5.8088 Accuracy 0.1457
# Epoch 11 Batch 2200 Loss 5.8090 Accuracy 0.1457
# Epoch 11 Batch 2250 Loss 5.8097 Accuracy 0.1457
# Epoch 11 Batch 2300 Loss 5.8107 Accuracy 0.1456
# Epoch 11 Batch 2350 Loss 5.8106 Accuracy 0.1456
# Epoch 11 Batch 2400 Loss 5.8107 Accuracy 0.1457
# Epoch 11 Batch 2450 Loss 5.8108 Accuracy 0.1456
# Epoch 11 Batch 2500 Loss 5.8107 Accuracy 0.1457
# Epoch 11 Batch 2550 Loss 5.8109 Accuracy 0.1457
# Epoch 11 Batch 2600 Loss 5.8112 Accuracy 0.1457
# Epoch 11 Loss 5.8111 Accuracy 0.1457
# Time taken for 1 epoch: 174.3263874053955 secs
#
# Epoch 12 Batch 0 Loss 5.8161 Accuracy 0.1359
# Epoch 12 Batch 50 Loss 5.8007 Accuracy 0.1462
# Epoch 12 Batch 100 Loss 5.7906 Accuracy 0.1472
# Epoch 12 Batch 150 Loss 5.7990 Accuracy 0.1466
# Epoch 12 Batch 200 Loss 5.8074 Accuracy 0.1462
# Epoch 12 Batch 250 Loss 5.8089 Accuracy 0.1460
# Epoch 12 Batch 300 Loss 5.8125 Accuracy 0.1457
# Epoch 12 Batch 350 Loss 5.8129 Accuracy 0.1459
# Epoch 12 Batch 400 Loss 5.8126 Accuracy 0.1457
# Epoch 12 Batch 450 Loss 5.8145 Accuracy 0.1455
# Epoch 12 Batch 500 Loss 5.8119 Accuracy 0.1457
# Epoch 12 Batch 550 Loss 5.8113 Accuracy 0.1459
# Epoch 12 Batch 600 Loss 5.8119 Accuracy 0.1456
# Epoch 12 Batch 650 Loss 5.8113 Accuracy 0.1457
# Epoch 12 Batch 700 Loss 5.8091 Accuracy 0.1458
# Epoch 12 Batch 750 Loss 5.8085 Accuracy 0.1458
# Epoch 12 Batch 800 Loss 5.8078 Accuracy 0.1459
# Epoch 12 Batch 850 Loss 5.8076 Accuracy 0.1460
# Epoch 12 Batch 900 Loss 5.8083 Accuracy 0.1459
# Epoch 12 Batch 950 Loss 5.8072 Accuracy 0.1459
# Epoch 12 Batch 1000 Loss 5.8077 Accuracy 0.1460
# Epoch 12 Batch 1050 Loss 5.8175 Accuracy 0.1454
# Epoch 12 Batch 1100 Loss 5.8232 Accuracy 0.1452
# Epoch 12 Batch 1150 Loss 5.8276 Accuracy 0.1449
# Epoch 12 Batch 1200 Loss 5.8299 Accuracy 0.1447
# Epoch 12 Batch 1250 Loss 5.8329 Accuracy 0.1445
# Epoch 12 Batch 1300 Loss 5.8353 Accuracy 0.1443
# Epoch 12 Batch 1350 Loss 5.8375 Accuracy 0.1441
# Epoch 12 Batch 1400 Loss 5.8393 Accuracy 0.1441
# Epoch 12 Batch 1450 Loss 5.8413 Accuracy 0.1440
# Epoch 12 Batch 1500 Loss 5.8428 Accuracy 0.1439
# Epoch 12 Batch 1550 Loss 5.8440 Accuracy 0.1438
# Epoch 12 Batch 1600 Loss 5.8447 Accuracy 0.1438
# Epoch 12 Batch 1650 Loss 5.8454 Accuracy 0.1438
# Epoch 12 Batch 1700 Loss 5.8458 Accuracy 0.1438
# Epoch 12 Batch 1750 Loss 5.8462 Accuracy 0.1438
# Epoch 12 Batch 1800 Loss 5.8461 Accuracy 0.1439
# Epoch 12 Batch 1850 Loss 5.8461 Accuracy 0.1439
# Epoch 12 Batch 1900 Loss 5.8461 Accuracy 0.1439
# Epoch 12 Batch 1950 Loss 5.8457 Accuracy 0.1440
# Epoch 12 Batch 2000 Loss 5.8453 Accuracy 0.1440
# Epoch 12 Batch 2050 Loss 5.8447 Accuracy 0.1440
# Epoch 12 Batch 2100 Loss 5.8446 Accuracy 0.1440
# Epoch 12 Batch 2150 Loss 5.8444 Accuracy 0.1440
# Epoch 12 Batch 2200 Loss 5.8478 Accuracy 0.1436
# Epoch 12 Batch 2250 Loss 5.8503 Accuracy 0.1432
# Epoch 12 Batch 2300 Loss 5.8513 Accuracy 0.1431
# Epoch 12 Batch 2350 Loss 5.8518 Accuracy 0.1431
# Epoch 12 Batch 2400 Loss 5.8519 Accuracy 0.1431
# Epoch 12 Batch 2450 Loss 5.8527 Accuracy 0.1430
# Epoch 12 Batch 2500 Loss 5.8522 Accuracy 0.1430
# Epoch 12 Batch 2550 Loss 5.8525 Accuracy 0.1430
# Epoch 12 Batch 2600 Loss 5.8526 Accuracy 0.1430
# Epoch 12 Loss 5.8525 Accuracy 0.1430
# Time taken for 1 epoch: 180.20442152023315 secs
#
# Epoch 13 Batch 0 Loss 5.9866 Accuracy 0.1316
# Epoch 13 Batch 50 Loss 5.8234 Accuracy 0.1432
# Epoch 13 Batch 100 Loss 5.8311 Accuracy 0.1432
# Epoch 13 Batch 150 Loss 5.8279 Accuracy 0.1438
# Epoch 13 Batch 200 Loss 5.8248 Accuracy 0.1447
# Epoch 13 Batch 250 Loss 5.8229 Accuracy 0.1447
# Epoch 13 Batch 300 Loss 5.8235 Accuracy 0.1443
# Epoch 13 Batch 350 Loss 5.8251 Accuracy 0.1441
# Epoch 13 Batch 400 Loss 5.8263 Accuracy 0.1439
# Epoch 13 Batch 450 Loss 5.8274 Accuracy 0.1439
# Epoch 13 Batch 500 Loss 5.8294 Accuracy 0.1438
# Epoch 13 Batch 550 Loss 5.8310 Accuracy 0.1437
# Epoch 13 Batch 600 Loss 5.8342 Accuracy 0.1434
# Epoch 13 Batch 650 Loss 5.8432 Accuracy 0.1422
# Epoch 13 Batch 700 Loss 5.8717 Accuracy 0.1380
# Epoch 13 Batch 750 Loss 5.8951 Accuracy 0.1339
# Epoch 13 Batch 800 Loss 5.9108 Accuracy 0.1308
# Epoch 13 Batch 850 Loss 5.9220 Accuracy 0.1282
# Epoch 13 Batch 900 Loss 5.9321 Accuracy 0.1260
# Epoch 13 Batch 950 Loss 5.9404 Accuracy 0.1242
# Epoch 13 Batch 1000 Loss 5.9489 Accuracy 0.1225
# Epoch 13 Batch 1050 Loss 5.9557 Accuracy 0.1209
# Epoch 13 Batch 1100 Loss 5.9629 Accuracy 0.1196
# Epoch 13 Batch 1150 Loss 5.9685 Accuracy 0.1184
# Epoch 13 Batch 1200 Loss 5.9763 Accuracy 0.1172
# Epoch 13 Batch 1250 Loss 5.9820 Accuracy 0.1161
# Epoch 13 Batch 1300 Loss 5.9870 Accuracy 0.1152
# Epoch 13 Batch 1350 Loss 5.9918 Accuracy 0.1143
# Epoch 13 Batch 1400 Loss 5.9957 Accuracy 0.1135
# Epoch 13 Batch 1450 Loss 5.9993 Accuracy 0.1128
# Epoch 13 Batch 1500 Loss 6.0032 Accuracy 0.1122
# Epoch 13 Batch 1550 Loss 6.0064 Accuracy 0.1116
# Epoch 13 Batch 1600 Loss 6.0096 Accuracy 0.1111
# Epoch 13 Batch 1650 Loss 6.0129 Accuracy 0.1105
# Epoch 13 Batch 1700 Loss 6.0151 Accuracy 0.1101
# Epoch 13 Batch 1750 Loss 6.0178 Accuracy 0.1096
# Epoch 13 Batch 1800 Loss 6.0194 Accuracy 0.1092
# Epoch 13 Batch 1850 Loss 6.0220 Accuracy 0.1088
# Epoch 13 Batch 1900 Loss 6.0238 Accuracy 0.1084
# Epoch 13 Batch 1950 Loss 6.0248 Accuracy 0.1080
# Epoch 13 Batch 2000 Loss 6.0263 Accuracy 0.1077
# Epoch 13 Batch 2050 Loss 6.0278 Accuracy 0.1074
# Epoch 13 Batch 2100 Loss 6.0287 Accuracy 0.1071
# Epoch 13 Batch 2150 Loss 6.0294 Accuracy 0.1068
# Epoch 13 Batch 2200 Loss 6.0295 Accuracy 0.1065
# Epoch 13 Batch 2250 Loss 6.0297 Accuracy 0.1063
# Epoch 13 Batch 2300 Loss 6.0301 Accuracy 0.1060
# Epoch 13 Batch 2350 Loss 6.0306 Accuracy 0.1058
# Epoch 13 Batch 2400 Loss 6.0304 Accuracy 0.1056
# Epoch 13 Batch 2450 Loss 6.0304 Accuracy 0.1054
# Epoch 13 Batch 2500 Loss 6.0311 Accuracy 0.1052
# Epoch 13 Batch 2550 Loss 6.0313 Accuracy 0.1049
# Epoch 13 Batch 2600 Loss 6.0316 Accuracy 0.1048
# Epoch 13 Loss 6.0314 Accuracy 0.1047
# Time taken for 1 epoch: 185.46028065681458 secs
#
# Epoch 14 Batch 0 Loss 5.9724 Accuracy 0.1041
# Epoch 14 Batch 50 Loss 6.0452 Accuracy 0.0956
# Epoch 14 Batch 100 Loss 6.0396 Accuracy 0.0955
# Epoch 14 Batch 150 Loss 6.0285 Accuracy 0.0955
# Epoch 14 Batch 200 Loss 6.0252 Accuracy 0.0951
# Epoch 14 Batch 250 Loss 6.0240 Accuracy 0.0952
# Epoch 14 Batch 300 Loss 6.0246 Accuracy 0.0951
# Epoch 14 Batch 350 Loss 6.0229 Accuracy 0.0952
# Epoch 14 Batch 400 Loss 6.0276 Accuracy 0.0950
# Epoch 14 Batch 450 Loss 6.0260 Accuracy 0.0949
# Epoch 14 Batch 500 Loss 6.0247 Accuracy 0.0950
# Epoch 14 Batch 550 Loss 6.0242 Accuracy 0.0952
# Epoch 14 Batch 600 Loss 6.0246 Accuracy 0.0953
# Epoch 14 Batch 650 Loss 6.0258 Accuracy 0.0953
# Epoch 14 Batch 700 Loss 6.0261 Accuracy 0.0953
# Epoch 14 Batch 750 Loss 6.0260 Accuracy 0.0954
# Epoch 14 Batch 800 Loss 6.0263 Accuracy 0.0953
# Epoch 14 Batch 850 Loss 6.0269 Accuracy 0.0954
# Epoch 14 Batch 900 Loss 6.0271 Accuracy 0.0955
# Epoch 14 Batch 950 Loss 6.0270 Accuracy 0.0955
# Epoch 14 Batch 1000 Loss 6.0279 Accuracy 0.0954
# Epoch 14 Batch 1050 Loss 6.0294 Accuracy 0.0955
# Epoch 14 Batch 1100 Loss 6.0321 Accuracy 0.0953
# Epoch 14 Batch 1150 Loss 6.0332 Accuracy 0.0953
# Epoch 14 Batch 1200 Loss 6.0341 Accuracy 0.0953
# Epoch 14 Batch 1250 Loss 6.0341 Accuracy 0.0954
# Epoch 14 Batch 1300 Loss 6.0350 Accuracy 0.0954
# Epoch 14 Batch 1350 Loss 6.0358 Accuracy 0.0954
# Epoch 14 Batch 1400 Loss 6.0365 Accuracy 0.0954
# Epoch 14 Batch 1450 Loss 6.0370 Accuracy 0.0954
# Epoch 14 Batch 1500 Loss 6.0364 Accuracy 0.0954
# Epoch 14 Batch 1550 Loss 6.0362 Accuracy 0.0955
# Epoch 14 Batch 1600 Loss 6.0367 Accuracy 0.0955
# Epoch 14 Batch 1650 Loss 6.0366 Accuracy 0.0956
# Epoch 14 Batch 1700 Loss 6.0371 Accuracy 0.0956
# Epoch 14 Batch 1750 Loss 6.0375 Accuracy 0.0956
# Epoch 14 Batch 1800 Loss 6.0377 Accuracy 0.0956
# Epoch 14 Batch 1850 Loss 6.0379 Accuracy 0.0957
# Epoch 14 Batch 1900 Loss 6.0376 Accuracy 0.0957
# Epoch 14 Batch 1950 Loss 6.0373 Accuracy 0.0957
# Epoch 14 Batch 2000 Loss 6.0371 Accuracy 0.0958
# Epoch 14 Batch 2050 Loss 6.0365 Accuracy 0.0958
# Epoch 14 Batch 2100 Loss 6.0364 Accuracy 0.0958
# Epoch 14 Batch 2150 Loss 6.0362 Accuracy 0.0959
# Epoch 14 Batch 2200 Loss 6.0354 Accuracy 0.0959
# Epoch 14 Batch 2250 Loss 6.0354 Accuracy 0.0959
# Epoch 14 Batch 2300 Loss 6.0349 Accuracy 0.0959
# Epoch 14 Batch 2350 Loss 6.0347 Accuracy 0.0959
# Epoch 14 Batch 2400 Loss 6.0342 Accuracy 0.0960
# Epoch 14 Batch 2450 Loss 6.0338 Accuracy 0.0960
# Epoch 14 Batch 2500 Loss 6.0336 Accuracy 0.0960
# Epoch 14 Batch 2550 Loss 6.0332 Accuracy 0.0960
# Epoch 14 Batch 2600 Loss 6.0334 Accuracy 0.0961
# Epoch 14 Loss 6.0329 Accuracy 0.0961
# Time taken for 1 epoch: 187.00227904319763 secs
#
# Epoch 15 Batch 0 Loss 5.8927 Accuracy 0.1049
# Epoch 15 Batch 50 Loss 6.0158 Accuracy 0.0981
# Epoch 15 Batch 100 Loss 6.0059 Accuracy 0.0977
# Epoch 15 Batch 150 Loss 6.0082 Accuracy 0.0976
# Epoch 15 Batch 200 Loss 6.0046 Accuracy 0.0977
# Epoch 15 Batch 250 Loss 6.0084 Accuracy 0.0973
# Epoch 15 Batch 300 Loss 6.0063 Accuracy 0.0974
# Epoch 15 Batch 350 Loss 6.0062 Accuracy 0.0973
# Epoch 15 Batch 400 Loss 6.0054 Accuracy 0.0972
# Epoch 15 Batch 450 Loss 6.0043 Accuracy 0.0972
# Epoch 15 Batch 500 Loss 6.0040 Accuracy 0.0971
# Epoch 15 Batch 550 Loss 6.0041 Accuracy 0.0971
# Epoch 15 Batch 600 Loss 6.0064 Accuracy 0.0971
# Epoch 15 Batch 650 Loss 6.0115 Accuracy 0.0970
# Epoch 15 Batch 700 Loss 6.0171 Accuracy 0.0969
# Epoch 15 Batch 750 Loss 6.0205 Accuracy 0.0969
# Epoch 15 Batch 800 Loss 6.0237 Accuracy 0.0969
# Epoch 15 Batch 850 Loss 6.0277 Accuracy 0.0968
# Epoch 15 Batch 900 Loss 6.0311 Accuracy 0.0966
# Epoch 15 Batch 950 Loss 6.0336 Accuracy 0.0966
# Epoch 15 Batch 1000 Loss 6.0363 Accuracy 0.0965
# Epoch 15 Batch 1050 Loss 6.0375 Accuracy 0.0965
# Epoch 15 Batch 1100 Loss 6.0386 Accuracy 0.0965
# Epoch 15 Batch 1150 Loss 6.0402 Accuracy 0.0965
# Epoch 15 Batch 1200 Loss 6.0413 Accuracy 0.0965
# Epoch 15 Batch 1250 Loss 6.0429 Accuracy 0.0965
# Epoch 15 Batch 1300 Loss 6.0439 Accuracy 0.0964
# Epoch 15 Batch 1350 Loss 6.0443 Accuracy 0.0964
# Epoch 15 Batch 1400 Loss 6.0451 Accuracy 0.0964
# Epoch 15 Batch 1450 Loss 6.0447 Accuracy 0.0964
# Epoch 15 Batch 1500 Loss 6.0451 Accuracy 0.0964
# Epoch 15 Batch 1550 Loss 6.0448 Accuracy 0.0964
# Epoch 15 Batch 1600 Loss 6.0457 Accuracy 0.0964
# Epoch 15 Batch 1650 Loss 6.0461 Accuracy 0.0965
# Epoch 15 Batch 1700 Loss 6.0462 Accuracy 0.0964
# Epoch 15 Batch 1750 Loss 6.0467 Accuracy 0.0965
# Epoch 15 Batch 1800 Loss 6.0470 Accuracy 0.0964
# Epoch 15 Batch 1850 Loss 6.0465 Accuracy 0.0964
# Epoch 15 Batch 1900 Loss 6.0471 Accuracy 0.0964
# Epoch 15 Batch 1950 Loss 6.0469 Accuracy 0.0965
# Epoch 15 Batch 2000 Loss 6.0466 Accuracy 0.0965
# Epoch 15 Batch 2050 Loss 6.0464 Accuracy 0.0965
# Epoch 15 Batch 2100 Loss 6.0458 Accuracy 0.0965
# Epoch 15 Batch 2150 Loss 6.0456 Accuracy 0.0965
# Epoch 15 Batch 2200 Loss 6.0452 Accuracy 0.0966
# Epoch 15 Batch 2250 Loss 6.0445 Accuracy 0.0966
# Epoch 15 Batch 2300 Loss 6.0439 Accuracy 0.0966
# Epoch 15 Batch 2350 Loss 6.0437 Accuracy 0.0966
# Epoch 15 Batch 2400 Loss 6.0432 Accuracy 0.0966
# Epoch 15 Batch 2450 Loss 6.0424 Accuracy 0.0967
# Epoch 15 Batch 2500 Loss 6.0420 Accuracy 0.0967
# Epoch 15 Batch 2550 Loss 6.0414 Accuracy 0.0967
# Epoch 15 Batch 2600 Loss 6.0408 Accuracy 0.0967
# Saving checkpoint for epoch 15 at ./checkpoints/train/ckpt-3
# Epoch 15 Loss 6.0407 Accuracy 0.0967
# Time taken for 1 epoch: 187.65034461021423 secs
#
# Epoch 16 Batch 0 Loss 5.9213 Accuracy 0.1078
# Epoch 16 Batch 50 Loss 6.0075 Accuracy 0.0984
# Epoch 16 Batch 100 Loss 6.0009 Accuracy 0.0985
# Epoch 16 Batch 150 Loss 5.9980 Accuracy 0.0989
# Epoch 16 Batch 200 Loss 6.0038 Accuracy 0.0982
# Epoch 16 Batch 250 Loss 6.0041 Accuracy 0.0983
# Epoch 16 Batch 300 Loss 6.0029 Accuracy 0.0983
# Epoch 16 Batch 350 Loss 6.0006 Accuracy 0.0984
# Epoch 16 Batch 400 Loss 6.0025 Accuracy 0.0983
# Epoch 16 Batch 450 Loss 6.0018 Accuracy 0.0983
# Epoch 16 Batch 500 Loss 6.0021 Accuracy 0.0983
# Epoch 16 Batch 550 Loss 5.9994 Accuracy 0.0983
# Epoch 16 Batch 600 Loss 5.9991 Accuracy 0.0983
# Epoch 16 Batch 650 Loss 5.9986 Accuracy 0.0984
# Epoch 16 Batch 700 Loss 5.9978 Accuracy 0.0984
# Epoch 16 Batch 750 Loss 5.9973 Accuracy 0.0984
# Epoch 16 Batch 800 Loss 5.9983 Accuracy 0.0985
# Epoch 16 Batch 850 Loss 5.9974 Accuracy 0.0985
# Epoch 16 Batch 900 Loss 5.9968 Accuracy 0.0986
# Epoch 16 Batch 950 Loss 5.9963 Accuracy 0.0987
# Epoch 16 Batch 1000 Loss 5.9952 Accuracy 0.0988
# Epoch 16 Batch 1050 Loss 5.9949 Accuracy 0.0988
# Epoch 16 Batch 1100 Loss 5.9952 Accuracy 0.0987
# Epoch 16 Batch 1150 Loss 5.9949 Accuracy 0.0988
# Epoch 16 Batch 1200 Loss 5.9939 Accuracy 0.0988
# Epoch 16 Batch 1250 Loss 5.9937 Accuracy 0.0987
# Epoch 16 Batch 1300 Loss 5.9922 Accuracy 0.0987
# Epoch 16 Batch 1350 Loss 5.9926 Accuracy 0.0987
# Epoch 16 Batch 1400 Loss 5.9930 Accuracy 0.0987
# Epoch 16 Batch 1450 Loss 5.9925 Accuracy 0.0988
# Epoch 16 Batch 1500 Loss 5.9919 Accuracy 0.0988
# Epoch 16 Batch 1550 Loss 5.9911 Accuracy 0.0988
# Epoch 16 Batch 1600 Loss 5.9907 Accuracy 0.0989
# Epoch 16 Batch 1650 Loss 5.9899 Accuracy 0.0989
# Epoch 16 Batch 1700 Loss 5.9900 Accuracy 0.0990
# Epoch 16 Batch 1750 Loss 5.9892 Accuracy 0.0990
# Epoch 16 Batch 1800 Loss 5.9888 Accuracy 0.0991
# Epoch 16 Batch 1850 Loss 5.9886 Accuracy 0.0991
# Epoch 16 Batch 1900 Loss 5.9885 Accuracy 0.0991
# Epoch 16 Batch 1950 Loss 5.9875 Accuracy 0.0992
# Epoch 16 Batch 2000 Loss 5.9876 Accuracy 0.0992
# Epoch 16 Batch 2050 Loss 5.9867 Accuracy 0.0992
# Epoch 16 Batch 2100 Loss 5.9867 Accuracy 0.0993
# Epoch 16 Batch 2150 Loss 5.9859 Accuracy 0.0993
# Epoch 16 Batch 2200 Loss 5.9852 Accuracy 0.0993
# Epoch 16 Batch 2250 Loss 5.9848 Accuracy 0.0994
# Epoch 16 Batch 2300 Loss 5.9842 Accuracy 0.0994
# Epoch 16 Batch 2350 Loss 5.9841 Accuracy 0.0994
# Epoch 16 Batch 2400 Loss 5.9841 Accuracy 0.0994
# Epoch 16 Batch 2450 Loss 5.9835 Accuracy 0.0994
# Epoch 16 Batch 2500 Loss 5.9828 Accuracy 0.0994
# Epoch 16 Batch 2550 Loss 5.9824 Accuracy 0.0994
# Epoch 16 Batch 2600 Loss 5.9824 Accuracy 0.0995
# Epoch 16 Loss 5.9821 Accuracy 0.0995
# Time taken for 1 epoch: 186.34693813323975 secs
#
# Epoch 17 Batch 0 Loss 6.0191 Accuracy 0.1026
# Epoch 17 Batch 50 Loss 5.9399 Accuracy 0.1019
# Epoch 17 Batch 100 Loss 5.9446 Accuracy 0.1015
# Epoch 17 Batch 150 Loss 5.9411 Accuracy 0.1021
# Epoch 17 Batch 200 Loss 5.9464 Accuracy 0.1018
# Epoch 17 Batch 250 Loss 5.9453 Accuracy 0.1016
# Epoch 17 Batch 300 Loss 5.9468 Accuracy 0.1010
# Epoch 17 Batch 350 Loss 5.9458 Accuracy 0.1009
# Epoch 17 Batch 400 Loss 5.9486 Accuracy 0.1007
# Epoch 17 Batch 450 Loss 5.9477 Accuracy 0.1006
# Epoch 17 Batch 500 Loss 5.9503 Accuracy 0.1005
# Epoch 17 Batch 550 Loss 5.9500 Accuracy 0.1005
# Epoch 17 Batch 600 Loss 5.9510 Accuracy 0.1005
# Epoch 17 Batch 650 Loss 5.9502 Accuracy 0.1006
# Epoch 17 Batch 700 Loss 5.9484 Accuracy 0.1007
# Epoch 17 Batch 750 Loss 5.9491 Accuracy 0.1007
# Epoch 17 Batch 800 Loss 5.9502 Accuracy 0.1006
# Epoch 17 Batch 850 Loss 5.9491 Accuracy 0.1006
# Epoch 17 Batch 900 Loss 5.9494 Accuracy 0.1006
# Epoch 17 Batch 950 Loss 5.9497 Accuracy 0.1005
# Epoch 17 Batch 1000 Loss 5.9494 Accuracy 0.1004
# Epoch 17 Batch 1050 Loss 5.9486 Accuracy 0.1005
# Epoch 17 Batch 1100 Loss 5.9489 Accuracy 0.1004
# Epoch 17 Batch 1150 Loss 5.9490 Accuracy 0.1004
# Epoch 17 Batch 1200 Loss 5.9489 Accuracy 0.1004
# Epoch 17 Batch 1250 Loss 5.9491 Accuracy 0.1005
# Epoch 17 Batch 1300 Loss 5.9483 Accuracy 0.1006
# Epoch 17 Batch 1350 Loss 5.9484 Accuracy 0.1006
# Epoch 17 Batch 1400 Loss 5.9483 Accuracy 0.1006
# Epoch 17 Batch 1450 Loss 5.9487 Accuracy 0.1005
# Epoch 17 Batch 1500 Loss 5.9490 Accuracy 0.1005
# Epoch 17 Batch 1550 Loss 5.9489 Accuracy 0.1006
# Epoch 17 Batch 1600 Loss 5.9486 Accuracy 0.1006
# Epoch 17 Batch 1650 Loss 5.9488 Accuracy 0.1007
# Epoch 17 Batch 1700 Loss 5.9491 Accuracy 0.1006
# Epoch 17 Batch 1750 Loss 5.9486 Accuracy 0.1007
# Epoch 17 Batch 1800 Loss 5.9482 Accuracy 0.1007
# Epoch 17 Batch 1850 Loss 5.9486 Accuracy 0.1007
# Epoch 17 Batch 1900 Loss 5.9487 Accuracy 0.1007
# Epoch 17 Batch 1950 Loss 5.9483 Accuracy 0.1007
# Epoch 17 Batch 2000 Loss 5.9482 Accuracy 0.1008
# Epoch 17 Batch 2050 Loss 5.9482 Accuracy 0.1008
# Epoch 17 Batch 2100 Loss 5.9477 Accuracy 0.1009
# Epoch 17 Batch 2150 Loss 5.9471 Accuracy 0.1009
# Epoch 17 Batch 2200 Loss 5.9476 Accuracy 0.1009
# Epoch 17 Batch 2250 Loss 5.9473 Accuracy 0.1009
# Epoch 17 Batch 2300 Loss 5.9472 Accuracy 0.1009
# Epoch 17 Batch 2350 Loss 5.9471 Accuracy 0.1009
# Epoch 17 Batch 2400 Loss 5.9464 Accuracy 0.1010
# Epoch 17 Batch 2450 Loss 5.9464 Accuracy 0.1010
# Epoch 17 Batch 2500 Loss 5.9463 Accuracy 0.1010
# Epoch 17 Batch 2550 Loss 5.9462 Accuracy 0.1010
# Epoch 17 Batch 2600 Loss 5.9461 Accuracy 0.1011
# Epoch 17 Loss 5.9461 Accuracy 0.1011
# Time taken for 1 epoch: 186.5785129070282 secs
#
# Epoch 18 Batch 0 Loss 6.0146 Accuracy 0.1040
# Epoch 18 Batch 50 Loss 5.9340 Accuracy 0.1020
# Epoch 18 Batch 100 Loss 5.9229 Accuracy 0.1024
# Epoch 18 Batch 150 Loss 5.9210 Accuracy 0.1021
# Epoch 18 Batch 200 Loss 5.9181 Accuracy 0.1024
# Epoch 18 Batch 250 Loss 5.9188 Accuracy 0.1026
# Epoch 18 Batch 300 Loss 5.9224 Accuracy 0.1023
# Epoch 18 Batch 350 Loss 5.9238 Accuracy 0.1021
# Epoch 18 Batch 400 Loss 5.9235 Accuracy 0.1022
# Epoch 18 Batch 450 Loss 5.9252 Accuracy 0.1021
# Epoch 18 Batch 500 Loss 5.9257 Accuracy 0.1020
# Epoch 18 Batch 550 Loss 5.9259 Accuracy 0.1022
# Epoch 18 Batch 600 Loss 5.9250 Accuracy 0.1022
# Epoch 18 Batch 650 Loss 5.9249 Accuracy 0.1022
# Epoch 18 Batch 700 Loss 5.9271 Accuracy 0.1021
# Epoch 18 Batch 750 Loss 5.9275 Accuracy 0.1019
# Epoch 18 Batch 800 Loss 5.9276 Accuracy 0.1019
# Epoch 18 Batch 850 Loss 5.9283 Accuracy 0.1019
# Epoch 18 Batch 900 Loss 5.9292 Accuracy 0.1018
# Epoch 18 Batch 950 Loss 5.9315 Accuracy 0.1017
# Epoch 18 Batch 1000 Loss 5.9322 Accuracy 0.1016
# Epoch 18 Batch 1050 Loss 5.9327 Accuracy 0.1016
# Epoch 18 Batch 1100 Loss 5.9323 Accuracy 0.1015
# Epoch 18 Batch 1150 Loss 5.9322 Accuracy 0.1015
# Epoch 18 Batch 1200 Loss 5.9315 Accuracy 0.1016
# Epoch 18 Batch 1250 Loss 5.9309 Accuracy 0.1016
# Epoch 18 Batch 1300 Loss 5.9309 Accuracy 0.1016
# Epoch 18 Batch 1350 Loss 5.9312 Accuracy 0.1016
# Epoch 18 Batch 1400 Loss 5.9306 Accuracy 0.1016
# Epoch 18 Batch 1450 Loss 5.9308 Accuracy 0.1016
# Epoch 18 Batch 1500 Loss 5.9307 Accuracy 0.1016
# Epoch 18 Batch 1550 Loss 5.9305 Accuracy 0.1016
# Epoch 18 Batch 1600 Loss 5.9305 Accuracy 0.1017
# Epoch 18 Batch 1650 Loss 5.9303 Accuracy 0.1017
# Epoch 18 Batch 1700 Loss 5.9311 Accuracy 0.1017
# Epoch 18 Batch 1750 Loss 5.9309 Accuracy 0.1018
# Epoch 18 Batch 1800 Loss 5.9312 Accuracy 0.1018
# Epoch 18 Batch 1850 Loss 5.9309 Accuracy 0.1018
# Epoch 18 Batch 1900 Loss 5.9307 Accuracy 0.1018
# Epoch 18 Batch 1950 Loss 5.9308 Accuracy 0.1018
# Epoch 18 Batch 2000 Loss 5.9302 Accuracy 0.1019
# Epoch 18 Batch 2050 Loss 5.9299 Accuracy 0.1019
# Epoch 18 Batch 2100 Loss 5.9298 Accuracy 0.1019
# Epoch 18 Batch 2150 Loss 5.9303 Accuracy 0.1018
# Epoch 18 Batch 2200 Loss 5.9303 Accuracy 0.1019
# Epoch 18 Batch 2250 Loss 5.9307 Accuracy 0.1018
# Epoch 18 Batch 2300 Loss 5.9306 Accuracy 0.1018
# Epoch 18 Batch 2350 Loss 5.9303 Accuracy 0.1019
# Epoch 18 Batch 2400 Loss 5.9305 Accuracy 0.1018
# Epoch 18 Batch 2450 Loss 5.9305 Accuracy 0.1018
# Epoch 18 Batch 2500 Loss 5.9305 Accuracy 0.1018
# Epoch 18 Batch 2550 Loss 5.9307 Accuracy 0.1018
# Epoch 18 Batch 2600 Loss 5.9306 Accuracy 0.1018
# Epoch 18 Loss 5.9307 Accuracy 0.1018
# Time taken for 1 epoch: 185.88986158370972 secs
#
# Epoch 19 Batch 0 Loss 5.8847 Accuracy 0.1065
# Epoch 19 Batch 50 Loss 5.9234 Accuracy 0.1015
# Epoch 19 Batch 100 Loss 5.8895 Accuracy 0.1159
# Epoch 19 Batch 150 Loss 5.8661 Accuracy 0.1248
# Epoch 19 Batch 200 Loss 5.8396 Accuracy 0.1302
# Epoch 19 Batch 250 Loss 5.8259 Accuracy 0.1334
# Epoch 19 Batch 300 Loss 5.8236 Accuracy 0.1356
# Epoch 19 Batch 350 Loss 5.8189 Accuracy 0.1372
# Epoch 19 Batch 400 Loss 5.8238 Accuracy 0.1374
# Epoch 19 Batch 450 Loss 5.8423 Accuracy 0.1368
# Epoch 19 Batch 500 Loss 5.8513 Accuracy 0.1368
# Epoch 19 Batch 550 Loss 5.8515 Accuracy 0.1371
# Epoch 19 Batch 600 Loss 5.8591 Accuracy 0.1367
# Epoch 19 Batch 650 Loss 5.8634 Accuracy 0.1367
# Epoch 19 Batch 700 Loss 5.8655 Accuracy 0.1368
# Epoch 19 Batch 750 Loss 5.8671 Accuracy 0.1371
# Epoch 19 Batch 800 Loss 5.8724 Accuracy 0.1370
# Epoch 19 Batch 850 Loss 5.8739 Accuracy 0.1372
# Epoch 19 Batch 900 Loss 5.8751 Accuracy 0.1373
# Epoch 19 Batch 950 Loss 5.8758 Accuracy 0.1375
# Epoch 19 Batch 1000 Loss 5.8766 Accuracy 0.1375
# Epoch 19 Batch 1050 Loss 5.8767 Accuracy 0.1376
# Epoch 19 Batch 1100 Loss 5.8784 Accuracy 0.1375
# Epoch 19 Batch 1150 Loss 5.8782 Accuracy 0.1376
# Epoch 19 Batch 1200 Loss 5.8802 Accuracy 0.1375
# Epoch 19 Batch 1250 Loss 5.8824 Accuracy 0.1375
# Epoch 19 Batch 1300 Loss 5.8877 Accuracy 0.1372
# Epoch 19 Batch 1350 Loss 5.8914 Accuracy 0.1372
# Epoch 19 Batch 1400 Loss 5.8948 Accuracy 0.1370
# ...
# Epoch 19 Batch 2500 Loss 5.8931 Accuracy 0.1383
# Epoch 19 Batch 2550 Loss 5.8923 Accuracy 0.1384
# Epoch 19 Batch 2600 Loss 5.8912 Accuracy 0.1385
# Epoch 19 Loss 5.8904 Accuracy 0.1386
# Time taken for 1 epoch: 186.29336380958557 secs
#
# Epoch 20 Batch 0 Loss 5.7165 Accuracy 0.1461
# Epoch 20 Batch 50 Loss 5.8374 Accuracy 0.1451
# Epoch 20 Batch 100 Loss 5.8759 Accuracy 0.1411
# Epoch 20 Batch 150 Loss 5.8748 Accuracy 0.1410
# Epoch 20 Batch 200 Loss 5.8705 Accuracy 0.1412
# Epoch 20 Batch 250 Loss 5.8678 Accuracy 0.1415
# Epoch 20 Batch 300 Loss 5.8721 Accuracy 0.1409
# Epoch 20 Batch 350 Loss 5.8852 Accuracy 0.1399
# Epoch 20 Batch 400 Loss 5.8900 Accuracy 0.1394
# Epoch 20 Batch 450 Loss 5.8946 Accuracy 0.1388
# Epoch 20 Batch 500 Loss 5.8980 Accuracy 0.1378
# Epoch 20 Batch 550 Loss 5.9037 Accuracy 0.1370
# Epoch 20 Batch 600 Loss 5.9213 Accuracy 0.1351
# Epoch 20 Batch 650 Loss 5.9327 Accuracy 0.1339
# Epoch 20 Batch 700 Loss 5.9412 Accuracy 0.1330
# Epoch 20 Batch 750 Loss 5.9483 Accuracy 0.1322
# Epoch 20 Batch 800 Loss 5.9547 Accuracy 0.1315
# Epoch 20 Batch 850 Loss 5.9599 Accuracy 0.1309
# Epoch 20 Batch 900 Loss 5.9655 Accuracy 0.1303
# Epoch 20 Batch 950 Loss 5.9694 Accuracy 0.1299
# Epoch 20 Batch 1000 Loss 5.9714 Accuracy 0.1296
# Epoch 20 Batch 1050 Loss 5.9731 Accuracy 0.1294
# Epoch 20 Batch 1100 Loss 5.9748 Accuracy 0.1293
# Epoch 20 Batch 1150 Loss 5.9751 Accuracy 0.1292
# Epoch 20 Batch 1200 Loss 5.9754 Accuracy 0.1292
# Epoch 20 Batch 1250 Loss 5.9756 Accuracy 0.1293
# Epoch 20 Batch 1300 Loss 5.9768 Accuracy 0.1292
# Epoch 20 Batch 1350 Loss 5.9763 Accuracy 0.1291
# Epoch 20 Batch 1400 Loss 5.9767 Accuracy 0.1290
# Epoch 20 Batch 1450 Loss 5.9756 Accuracy 0.1290
# Epoch 20 Batch 1500 Loss 5.9759 Accuracy 0.1289
# Epoch 20 Batch 1550 Loss 5.9753 Accuracy 0.1288
# Epoch 20 Batch 1600 Loss 5.9752 Accuracy 0.1288
# Epoch 20 Batch 1650 Loss 5.9750 Accuracy 0.1288
# Epoch 20 Batch 1700 Loss 5.9750 Accuracy 0.1288
# Epoch 20 Batch 1750 Loss 5.9742 Accuracy 0.1288
# Epoch 20 Batch 1800 Loss 5.9732 Accuracy 0.1288
# Epoch 20 Batch 1850 Loss 5.9731 Accuracy 0.1288
# Epoch 20 Batch 1900 Loss 5.9751 Accuracy 0.1284
# Epoch 20 Batch 1950 Loss 5.9783 Accuracy 0.1275
# Epoch 20 Batch 2000 Loss 5.9815 Accuracy 0.1266
# Epoch 20 Batch 2050 Loss 5.9839 Accuracy 0.1258
# Epoch 20 Batch 2100 Loss 5.9866 Accuracy 0.1249
# Epoch 20 Batch 2150 Loss 5.9887 Accuracy 0.1242
# Epoch 20 Batch 2200 Loss 5.9914 Accuracy 0.1235
# Epoch 20 Batch 2250 Loss 5.9936 Accuracy 0.1228
# Epoch 20 Batch 2300 Loss 5.9948 Accuracy 0.1223
# Epoch 20 Batch 2350 Loss 5.9962 Accuracy 0.1217
# Epoch 20 Batch 2400 Loss 5.9974 Accuracy 0.1211
# Epoch 20 Batch 2450 Loss 5.9990 Accuracy 0.1206
# Epoch 20 Batch 2500 Loss 6.0004 Accuracy 0.1201
# Epoch 20 Batch 2550 Loss 6.0018 Accuracy 0.1196
# Epoch 20 Batch 2600 Loss 6.0028 Accuracy 0.1191
# Saving checkpoint for epoch 20 at ./checkpoints/train/ckpt-4
# Epoch 20 Loss 6.0032 Accuracy 0.1189
# Time taken for 1 epoch: 185.59704566001892 secs
#
# Epoch 21 Batch 0 Loss 6.1329 Accuracy 0.0978
# Epoch 21 Batch 50 Loss 6.0539 Accuracy 0.0968
# Epoch 21 Batch 100 Loss 6.0500 Accuracy 0.0964
# Epoch 21 Batch 150 Loss 6.0545 Accuracy 0.0966
# Epoch 21 Batch 200 Loss 6.0562 Accuracy 0.0959
# Epoch 21 Batch 250 Loss 6.0530 Accuracy 0.0959
# Epoch 21 Batch 300 Loss 6.0486 Accuracy 0.0960
# Epoch 21 Batch 350 Loss 6.0440 Accuracy 0.0960
# Epoch 21 Batch 400 Loss 6.0452 Accuracy 0.0962
# Epoch 21 Batch 450 Loss 6.0474 Accuracy 0.0963
# Epoch 21 Batch 500 Loss 6.0483 Accuracy 0.0966
# Epoch 21 Batch 550 Loss 6.0491 Accuracy 0.0970
# Epoch 21 Batch 600 Loss 6.0499 Accuracy 0.0972
# Epoch 21 Batch 650 Loss 6.0494 Accuracy 0.0973
# Epoch 21 Batch 700 Loss 6.0507 Accuracy 0.0971
# Epoch 21 Batch 750 Loss 6.0523 Accuracy 0.0970
# Epoch 21 Batch 800 Loss 6.0527 Accuracy 0.0970
# Epoch 21 Batch 850 Loss 6.0536 Accuracy 0.0969
# Epoch 21 Batch 900 Loss 6.0529 Accuracy 0.0969
# Epoch 21 Batch 950 Loss 6.0529 Accuracy 0.0968
# Epoch 21 Batch 1000 Loss 6.0529 Accuracy 0.0969
# Epoch 21 Batch 1050 Loss 6.0525 Accuracy 0.0969
# Epoch 21 Batch 1100 Loss 6.0530 Accuracy 0.0969
# Epoch 21 Batch 1150 Loss 6.0549 Accuracy 0.0969
# Epoch 21 Batch 1200 Loss 6.0555 Accuracy 0.0968
# Epoch 21 Batch 1250 Loss 6.0564 Accuracy 0.0968
# Epoch 21 Batch 1300 Loss 6.0565 Accuracy 0.0968
# Epoch 21 Batch 1350 Loss 6.0566 Accuracy 0.0968
# Epoch 21 Batch 1400 Loss 6.0567 Accuracy 0.0969
# Epoch 21 Batch 1450 Loss 6.0566 Accuracy 0.0969
# Epoch 21 Batch 1500 Loss 6.0566 Accuracy 0.0968
# Epoch 21 Batch 1550 Loss 6.0568 Accuracy 0.0968
# Epoch 21 Batch 1600 Loss 6.0568 Accuracy 0.0969
# Epoch 21 Batch 1650 Loss 6.0562 Accuracy 0.0970
# Epoch 21 Batch 1700 Loss 6.0566 Accuracy 0.0970
# Epoch 21 Batch 1750 Loss 6.0566 Accuracy 0.0970
# Epoch 21 Batch 1800 Loss 6.0561 Accuracy 0.0970
# Epoch 21 Batch 1850 Loss 6.0559 Accuracy 0.0971
# Epoch 21 Batch 1900 Loss 6.0557 Accuracy 0.0971
# Epoch 21 Batch 1950 Loss 6.0556 Accuracy 0.0972
# Epoch 21 Batch 2000 Loss 6.0555 Accuracy 0.0971
# Epoch 21 Batch 2050 Loss 6.0555 Accuracy 0.0971
# Epoch 21 Batch 2100 Loss 6.0547 Accuracy 0.0971
# Epoch 21 Batch 2150 Loss 6.0546 Accuracy 0.0972
# Epoch 21 Batch 2200 Loss 6.0542 Accuracy 0.0971
# Epoch 21 Batch 2250 Loss 6.0542 Accuracy 0.0971
# Epoch 21 Batch 2300 Loss 6.0542 Accuracy 0.0971
# Epoch 21 Batch 2350 Loss 6.0545 Accuracy 0.0971
# Epoch 21 Batch 2400 Loss 6.0539 Accuracy 0.0972
# Epoch 21 Batch 2450 Loss 6.0537 Accuracy 0.0971
# Epoch 21 Batch 2500 Loss 6.0536 Accuracy 0.0971
# Epoch 21 Batch 2550 Loss 6.0532 Accuracy 0.0971
# Epoch 21 Batch 2600 Loss 6.0530 Accuracy 0.0972
# Epoch 21 Loss 6.0529 Accuracy 0.0971
# Time taken for 1 epoch: 185.10036778450012 secs
#
# Epoch 22 Batch 0 Loss 6.0751 Accuracy 0.0862
# Epoch 22 Batch 50 Loss 6.0312 Accuracy 0.0978
# Epoch 22 Batch 100 Loss 6.0245 Accuracy 0.0974
# Epoch 22 Batch 150 Loss 6.0311 Accuracy 0.0974
# Epoch 22 Batch 200 Loss 6.0306 Accuracy 0.0980
# Epoch 22 Batch 250 Loss 6.0268 Accuracy 0.0983
# Epoch 22 Batch 300 Loss 6.0256 Accuracy 0.0982
# Epoch 22 Batch 350 Loss 6.0256 Accuracy 0.0979
# Epoch 22 Batch 400 Loss 6.0262 Accuracy 0.0977
# Epoch 22 Batch 450 Loss 6.0290 Accuracy 0.0974
# Epoch 22 Batch 500 Loss 6.0319 Accuracy 0.0973
# Epoch 22 Batch 550 Loss 6.0372 Accuracy 0.0971
# Epoch 22 Batch 600 Loss 6.0397 Accuracy 0.0971
# Epoch 22 Batch 650 Loss 6.0418 Accuracy 0.0968
# Epoch 22 Batch 700 Loss 6.0441 Accuracy 0.0968
# Epoch 22 Batch 750 Loss 6.0428 Accuracy 0.0968
# Epoch 22 Batch 800 Loss 6.0428 Accuracy 0.0968
# Epoch 22 Batch 850 Loss 6.0423 Accuracy 0.0968
# Epoch 22 Batch 900 Loss 6.0417 Accuracy 0.0969
# Epoch 22 Batch 950 Loss 6.0421 Accuracy 0.0969
# Epoch 22 Batch 1000 Loss 6.0418 Accuracy 0.0969
# Epoch 22 Batch 1050 Loss 6.0421 Accuracy 0.0969
# Epoch 22 Batch 1100 Loss 6.0401 Accuracy 0.0970
# Epoch 22 Batch 1150 Loss 6.0408 Accuracy 0.0969
# Epoch 22 Batch 1200 Loss 6.0411 Accuracy 0.0970
# Epoch 22 Batch 1250 Loss 6.0407 Accuracy 0.0970
# Epoch 22 Batch 1300 Loss 6.0403 Accuracy 0.0970
# Epoch 22 Batch 1350 Loss 6.0387 Accuracy 0.0971
# Epoch 22 Batch 1400 Loss 6.0381 Accuracy 0.0971
# Epoch 22 Batch 1450 Loss 6.0375 Accuracy 0.0972
# Epoch 22 Batch 1500 Loss 6.0364 Accuracy 0.0973
# Epoch 22 Batch 1550 Loss 6.0356 Accuracy 0.0973
# Epoch 22 Batch 1600 Loss 6.0353 Accuracy 0.0973
# Epoch 22 Batch 1650 Loss 6.0349 Accuracy 0.0973
# Epoch 22 Batch 1700 Loss 6.0347 Accuracy 0.0974
# Epoch 22 Batch 1750 Loss 6.0346 Accuracy 0.0974
# Epoch 22 Batch 1800 Loss 6.0342 Accuracy 0.0974
# Epoch 22 Batch 1850 Loss 6.0334 Accuracy 0.0975
# Epoch 22 Batch 1900 Loss 6.0327 Accuracy 0.0975
# Epoch 22 Batch 1950 Loss 6.0324 Accuracy 0.0975
# Epoch 22 Batch 2000 Loss 6.0319 Accuracy 0.0976
# Epoch 22 Batch 2050 Loss 6.0316 Accuracy 0.0977
# Epoch 22 Batch 2100 Loss 6.0309 Accuracy 0.0977
# Epoch 22 Batch 2150 Loss 6.0307 Accuracy 0.0978
# Epoch 22 Batch 2200 Loss 6.0302 Accuracy 0.0978
# Epoch 22 Batch 2250 Loss 6.0297 Accuracy 0.0978
# Epoch 22 Batch 2300 Loss 6.0292 Accuracy 0.0979
# Epoch 22 Batch 2350 Loss 6.0286 Accuracy 0.0979
# Epoch 22 Batch 2400 Loss 6.0282 Accuracy 0.0979
# Epoch 22 Batch 2450 Loss 6.0273 Accuracy 0.0980
# Epoch 22 Batch 2500 Loss 6.0271 Accuracy 0.0980
# Epoch 22 Batch 2550 Loss 6.0267 Accuracy 0.0980
# Epoch 22 Batch 2600 Loss 6.0264 Accuracy 0.0980
# Epoch 22 Loss 6.0262 Accuracy 0.0980
# Time taken for 1 epoch: 186.024897813797 secs
#
# Epoch 23 Batch 0 Loss 5.8399 Accuracy 0.1136
# Epoch 23 Batch 50 Loss 6.0132 Accuracy 0.0987
# Epoch 23 Batch 100 Loss 6.0077 Accuracy 0.0998
# Epoch 23 Batch 150 Loss 6.0018 Accuracy 0.0999
# Epoch 23 Batch 200 Loss 5.9960 Accuracy 0.0998
# Epoch 23 Batch 250 Loss 5.9937 Accuracy 0.0997
# Epoch 23 Batch 300 Loss 5.9939 Accuracy 0.0996
# Epoch 23 Batch 350 Loss 5.9937 Accuracy 0.0996
# Epoch 23 Batch 400 Loss 5.9959 Accuracy 0.0995
# Epoch 23 Batch 450 Loss 5.9943 Accuracy 0.0996
# Epoch 23 Batch 500 Loss 5.9939 Accuracy 0.0994
# Epoch 23 Batch 550 Loss 5.9936 Accuracy 0.0994
# Epoch 23 Batch 600 Loss 5.9925 Accuracy 0.0995
# Epoch 23 Batch 650 Loss 5.9922 Accuracy 0.0994
# Epoch 23 Batch 700 Loss 5.9921 Accuracy 0.0994
# Epoch 23 Batch 750 Loss 5.9928 Accuracy 0.0993
# Epoch 23 Batch 800 Loss 5.9935 Accuracy 0.0991
# Epoch 23 Batch 850 Loss 5.9943 Accuracy 0.0992
# Epoch 23 Batch 900 Loss 5.9945 Accuracy 0.0992
# Epoch 23 Batch 950 Loss 5.9947 Accuracy 0.0993
# Epoch 23 Batch 1000 Loss 5.9949 Accuracy 0.0993
# Epoch 23 Batch 1050 Loss 5.9947 Accuracy 0.0993
# Epoch 23 Batch 1100 Loss 5.9952 Accuracy 0.0992
# Epoch 23 Batch 1150 Loss 5.9953 Accuracy 0.0992
# Epoch 23 Batch 1200 Loss 5.9955 Accuracy 0.0992
# Epoch 23 Batch 1250 Loss 5.9949 Accuracy 0.0992
# Epoch 23 Batch 1300 Loss 5.9948 Accuracy 0.0992
# Epoch 23 Batch 1350 Loss 5.9947 Accuracy 0.0993
# Epoch 23 Batch 1400 Loss 5.9945 Accuracy 0.0994
# Epoch 23 Batch 1450 Loss 5.9947 Accuracy 0.0994
# Epoch 23 Batch 1500 Loss 5.9936 Accuracy 0.0995
# Epoch 23 Batch 1550 Loss 5.9935 Accuracy 0.0996
# Epoch 23 Batch 1600 Loss 5.9935 Accuracy 0.0995
# Epoch 23 Batch 1650 Loss 5.9932 Accuracy 0.0996
# Epoch 23 Batch 1700 Loss 5.9934 Accuracy 0.0995
# Epoch 23 Batch 1750 Loss 5.9935 Accuracy 0.0996
# Epoch 23 Batch 1800 Loss 5.9935 Accuracy 0.0996
# Epoch 23 Batch 1850 Loss 5.9937 Accuracy 0.0996
# Epoch 23 Batch 1900 Loss 5.9939 Accuracy 0.0996
# Epoch 23 Batch 1950 Loss 5.9932 Accuracy 0.0997
# Epoch 23 Batch 2000 Loss 5.9934 Accuracy 0.0997
# Epoch 23 Batch 2050 Loss 5.9931 Accuracy 0.0997
# Epoch 23 Batch 2100 Loss 5.9933 Accuracy 0.0997
# Epoch 23 Batch 2150 Loss 5.9927 Accuracy 0.0997
# Epoch 23 Batch 2200 Loss 5.9926 Accuracy 0.0997
# Epoch 23 Batch 2250 Loss 5.9920 Accuracy 0.0997
# Epoch 23 Batch 2300 Loss 5.9918 Accuracy 0.0997
# Epoch 23 Batch 2350 Loss 5.9918 Accuracy 0.0997
# Epoch 23 Batch 2400 Loss 5.9914 Accuracy 0.0998
# Epoch 23 Batch 2450 Loss 5.9915 Accuracy 0.0998
# Epoch 23 Batch 2500 Loss 5.9917 Accuracy 0.0998
# Epoch 23 Batch 2550 Loss 5.9915 Accuracy 0.0997
# Epoch 23 Batch 2600 Loss 5.9909 Accuracy 0.0997
# Epoch 23 Loss 5.9909 Accuracy 0.0997
# Time taken for 1 epoch: 185.60048508644104 secs
#
# Epoch 24 Batch 0 Loss 5.9639 Accuracy 0.0972
# Epoch 24 Batch 50 Loss 5.9775 Accuracy 0.1016
# Epoch 24 Batch 100 Loss 5.9726 Accuracy 0.1011
# Epoch 24 Batch 150 Loss 5.9675 Accuracy 0.1012
# Epoch 24 Batch 200 Loss 5.9679 Accuracy 0.1011
# Epoch 24 Batch 250 Loss 5.9733 Accuracy 0.1005
# Epoch 24 Batch 300 Loss 5.9755 Accuracy 0.1003
# Epoch 24 Batch 350 Loss 5.9750 Accuracy 0.1002
# Epoch 24 Batch 400 Loss 5.9768 Accuracy 0.1002
# Epoch 24 Batch 450 Loss 5.9737 Accuracy 0.1003
# Epoch 24 Batch 500 Loss 5.9734 Accuracy 0.1002
# Epoch 24 Batch 550 Loss 5.9729 Accuracy 0.1003
# Epoch 24 Batch 600 Loss 5.9724 Accuracy 0.1002
# Epoch 24 Batch 650 Loss 5.9722 Accuracy 0.1001
# Epoch 24 Batch 700 Loss 5.9698 Accuracy 0.1002
# Epoch 24 Batch 750 Loss 5.9710 Accuracy 0.1002
# Epoch 24 Batch 800 Loss 5.9701 Accuracy 0.1003
# Epoch 24 Batch 850 Loss 5.9702 Accuracy 0.1004
# Epoch 24 Batch 900 Loss 5.9698 Accuracy 0.1004
# Epoch 24 Batch 950 Loss 5.9688 Accuracy 0.1005
# Epoch 24 Batch 1000 Loss 5.9689 Accuracy 0.1004
# Epoch 24 Batch 1050 Loss 5.9691 Accuracy 0.1004
# Epoch 24 Batch 1100 Loss 5.9683 Accuracy 0.1004
# Epoch 24 Batch 1150 Loss 5.9687 Accuracy 0.1005
# Epoch 24 Batch 1200 Loss 5.9694 Accuracy 0.1005
# Epoch 24 Batch 1250 Loss 5.9696 Accuracy 0.1005
# Epoch 24 Batch 1300 Loss 5.9694 Accuracy 0.1006
# Epoch 24 Batch 1350 Loss 5.9690 Accuracy 0.1006
# Epoch 24 Batch 1400 Loss 5.9696 Accuracy 0.1005
# Epoch 24 Batch 1450 Loss 5.9694 Accuracy 0.1006
# Epoch 24 Batch 1500 Loss 5.9694 Accuracy 0.1005
# Epoch 24 Batch 1550 Loss 5.9696 Accuracy 0.1005
# Epoch 24 Batch 1600 Loss 5.9698 Accuracy 0.1005
# Epoch 24 Batch 1650 Loss 5.9695 Accuracy 0.1006
# Epoch 24 Batch 1700 Loss 5.9696 Accuracy 0.1006
# Epoch 24 Batch 1750 Loss 5.9701 Accuracy 0.1006
# Epoch 24 Batch 1800 Loss 5.9695 Accuracy 0.1006
# Epoch 24 Batch 1850 Loss 5.9691 Accuracy 0.1007
# Epoch 24 Batch 1900 Loss 5.9688 Accuracy 0.1007
# Epoch 24 Batch 1950 Loss 5.9690 Accuracy 0.1007
# Epoch 24 Batch 2000 Loss 5.9692 Accuracy 0.1007
# Epoch 24 Batch 2050 Loss 5.9685 Accuracy 0.1007
# Epoch 24 Batch 2100 Loss 5.9680 Accuracy 0.1007
# Epoch 24 Batch 2150 Loss 5.9675 Accuracy 0.1007
# Epoch 24 Batch 2200 Loss 5.9674 Accuracy 0.1007
# Epoch 24 Batch 2250 Loss 5.9674 Accuracy 0.1007
# Epoch 24 Batch 2300 Loss 5.9670 Accuracy 0.1007
# Epoch 24 Batch 2350 Loss 5.9670 Accuracy 0.1008
# Epoch 24 Batch 2400 Loss 5.9670 Accuracy 0.1007
# Epoch 24 Batch 2450 Loss 5.9669 Accuracy 0.1008
# Epoch 24 Batch 2500 Loss 5.9665 Accuracy 0.1008
# Epoch 24 Batch 2550 Loss 5.9659 Accuracy 0.1009
# Epoch 24 Batch 2600 Loss 5.9654 Accuracy 0.1009
# Epoch 24 Loss 5.9657 Accuracy 0.1009
# Time taken for 1 epoch: 184.84285306930542 secs
#
# Epoch 25 Batch 0 Loss 5.9779 Accuracy 0.0904
# Epoch 25 Batch 50 Loss 5.9363 Accuracy 0.1033
# Epoch 25 Batch 100 Loss 5.9397 Accuracy 0.1016
# Epoch 25 Batch 150 Loss 5.9405 Accuracy 0.1013
# Epoch 25 Batch 200 Loss 5.9450 Accuracy 0.1014
# Epoch 25 Batch 250 Loss 5.9434 Accuracy 0.1014
# Epoch 25 Batch 300 Loss 5.9450 Accuracy 0.1016
# Epoch 25 Batch 350 Loss 5.9445 Accuracy 0.1014
# Epoch 25 Batch 400 Loss 5.9438 Accuracy 0.1014
# Epoch 25 Batch 450 Loss 5.9463 Accuracy 0.1014
# Epoch 25 Batch 500 Loss 5.9449 Accuracy 0.1017
# Epoch 25 Batch 550 Loss 5.9446 Accuracy 0.1019
# Epoch 25 Batch 600 Loss 5.9445 Accuracy 0.1021
# Epoch 25 Batch 650 Loss 5.9421 Accuracy 0.1035
# Epoch 25 Batch 700 Loss 5.9424 Accuracy 0.1038
# Epoch 25 Batch 750 Loss 5.9422 Accuracy 0.1050
# Epoch 25 Batch 800 Loss 5.9390 Accuracy 0.1067
# Epoch 25 Batch 850 Loss 5.9366 Accuracy 0.1085
# Epoch 25 Batch 900 Loss 5.9314 Accuracy 0.1103
# Epoch 25 Batch 950 Loss 5.9262 Accuracy 0.1121
# Epoch 25 Batch 1000 Loss 5.9210 Accuracy 0.1137
# Epoch 25 Batch 1050 Loss 5.9154 Accuracy 0.1152
# Epoch 25 Batch 1100 Loss 5.9124 Accuracy 0.1164
# Epoch 25 Batch 1150 Loss 5.9088 Accuracy 0.1177
# Epoch 25 Batch 1200 Loss 5.9043 Accuracy 0.1189
# Epoch 25 Batch 1250 Loss 5.9009 Accuracy 0.1199
# Epoch 25 Batch 1300 Loss 5.8974 Accuracy 0.1209
# Epoch 25 Batch 1350 Loss 5.8942 Accuracy 0.1219
# Epoch 25 Batch 1400 Loss 5.8906 Accuracy 0.1228
# Epoch 25 Batch 1450 Loss 5.8882 Accuracy 0.1237
# Epoch 25 Batch 1500 Loss 5.8862 Accuracy 0.1244
# Epoch 25 Batch 1550 Loss 5.8832 Accuracy 0.1251
# Epoch 25 Batch 1600 Loss 5.8806 Accuracy 0.1258
# Epoch 25 Batch 1650 Loss 5.8778 Accuracy 0.1265
# Epoch 25 Batch 1700 Loss 5.8760 Accuracy 0.1271
# Epoch 25 Batch 1750 Loss 5.8742 Accuracy 0.1276
# Epoch 25 Batch 1800 Loss 5.8725 Accuracy 0.1281
# Epoch 25 Batch 1850 Loss 5.8706 Accuracy 0.1287
# Epoch 25 Batch 1900 Loss 5.8687 Accuracy 0.1292
# Epoch 25 Batch 1950 Loss 5.8664 Accuracy 0.1297
# Epoch 25 Batch 2000 Loss 5.8648 Accuracy 0.1301
# Epoch 25 Batch 2050 Loss 5.8638 Accuracy 0.1305
# Epoch 25 Batch 2100 Loss 5.8620 Accuracy 0.1309
# Epoch 25 Batch 2150 Loss 5.8606 Accuracy 0.1313
# Epoch 25 Batch 2200 Loss 5.8594 Accuracy 0.1317
# Epoch 25 Batch 2250 Loss 5.8583 Accuracy 0.1320
# Epoch 25 Batch 2300 Loss 5.8571 Accuracy 0.1324
# Epoch 25 Batch 2350 Loss 5.8559 Accuracy 0.1326
# Epoch 25 Batch 2400 Loss 5.8549 Accuracy 0.1329
# Epoch 25 Batch 2450 Loss 5.8535 Accuracy 0.1332
# Epoch 25 Batch 2500 Loss 5.8522 Accuracy 0.1335
# Epoch 25 Batch 2550 Loss 5.8507 Accuracy 0.1338
# Epoch 25 Batch 2600 Loss 5.8493 Accuracy 0.1341
# Saving checkpoint for epoch 25 at ./checkpoints/train/ckpt-5
# Epoch 25 Loss 5.8489 Accuracy 0.1342
# Time taken for 1 epoch: 175.80826568603516 secs

# %% [markdown]
# Теперь можно оценить результат обучения модели

# %%
def evaluate(inp_sentence):
  start_token = [tokenizer_pt.vocab_size]
  end_token = [tokenizer_pt.vocab_size + 1]

  # inp sentence is portuguese, hence adding the start and end token
  inp_sentence = start_token + tokenizer_pt.encode(inp_sentence) + end_token
  encoder_input = tf.expand_dims(inp_sentence, 0)

  # as the target is english, the first word to the transformer should be the
  # english start token.
  decoder_input = [tokenizer_en.vocab_size]
  output = tf.expand_dims(decoder_input, 0)

  for i in range(MAX_LENGTH):
    enc_padding_mask, combined_mask, dec_padding_mask = create_masks(
        encoder_input, output)

    # predictions.shape == (batch_size, seq_len, vocab_size)
    predictions, attention_weights = transformer(encoder_input,
                                                 output,
                                                 False,
                                                 enc_padding_mask,
                                                 combined_mask,
                                                 dec_padding_mask)

    # select the last word from the seq_len dimension
    predictions = predictions[: ,-1:, :]  # (batch_size, 1, vocab_size)

    predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)

    # return the result if the predicted_id is equal to the end token
    if predicted_id == tokenizer_en.vocab_size+1:
      return tf.squeeze(output, axis=0), attention_weights

    # concatentate the predicted_id to the output which is given to the decoder
    # as its input.
    output = tf.concat([output, predicted_id], axis=-1)

  return tf.squeeze(output, axis=0), attention_weights

# %%
def plot_attention_weights(attention, sentence, result, layer):
  fig = plt.figure(figsize=(16, 8))

  sentence = tokenizer_pt.encode(sentence)

  attention = tf.squeeze(attention[layer], axis=0)

  for head in range(attention.shape[0]):
    ax = fig.add_subplot(2, 4, head+1)

    # plot the attention weights
    ax.matshow(attention[head][:-1, :], cmap='viridis')

    fontdict = {'fontsize': 10}

    ax.set_xticks(range(len(sentence)+2))
    ax.set_yticks(range(len(result)))

    ax.set_ylim(len(result)-1.5, -0.5)

    ax.set_xticklabels(
        ['<start>']+[tokenizer_pt.decode([i]) for i in sentence]+['<end>'],
        fontdict=fontdict, rotation=90)

    ax.set_yticklabels([tokenizer_en.decode([i]) for i in result
                        if i < tokenizer_en.vocab_size],
                       fontdict=fontdict)

    ax.set_xlabel('Head {}'.format(head+1))

  plt.tight_layout()
  plt.show()

# %%
#функция перевода
def translate(sentence, plot=''):
  result, attention_weights = evaluate(sentence)

  predicted_sentence = tokenizer_en.decode([i for i in result
                                            if i < tokenizer_en.vocab_size])

  print('Ввод: {}'.format(sentence))
  print('Предсказание переводчика: {}'.format(predicted_sentence))

  if plot:
    plot_attention_weights(attention_weights, sentence, result, plot)

# %%
translate("Мама мыла раму.")
# Out:
# Ввод: Мама мыла раму.
# Предсказание переводчика: thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank thank

# %%
translate("Туча мглою небо кроет, вихри снежные крутя.")
# Out:
# Ввод: Туча мглою небо кроет, вихри снежные крутя.
# Предсказание переводчика: this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this
